# %%
import os
import sys

import re
import pandas as pd
import networkx as nx
import tqdm
import random
import pickle
import json
import subprocess
import numpy as np
import httpx
import requests
import time

from dotenv import load_dotenv
from tqdm import tqdm

# Determine the project root directory for relative imports
try:
    # This will work in scripts where __file__ is defined
    current_dir = os.path.dirname(os.path.abspath(__file__))
    # Assuming "src" is parallel to the script folder
    project_root = os.path.abspath(os.path.join(current_dir, ".."))
except NameError:
    # In notebooks __file__ is not defined: assume we're in notebooks/riziv_dataset/
    project_root = os.path.abspath(os.path.join(os.getcwd(), "../.."))

src_path = os.path.join(project_root, "src")
if src_path not in sys.path:
    sys.path.append(src_path)

# Local application imports

#from main.ollama_utils import get_ollama_embedding

# %%
load_dotenv(os.path.join(project_root, ".env"))
response_gpu_temp = httpx.get(f"{os.getenv('NGROK_URL')}/health/gpu")

response_gpu_temp
# Out:
# <Response [200 OK]>

# %%
# Define the path to the BSARD dataset files
BSARD_data_path = os.path.join(project_root, "data", "BSARD_dataset")

# %%
with open(os.path.join(BSARD_data_path,"intermediate", "hybrid_graph_full.pkl"), 'rb') as f:
    G = pickle.load(f)

# %%
NGROK_URL = os.getenv("NGROK_URL")
API_TOKEN = os.getenv("API_KEY")

def get_ollama_embedding(input_text):

    response = requests.post(
        f"{NGROK_URL}/embed",
        headers={
            "Authorization": f"Bearer {API_TOKEN}",
                },
        json={
            "input": input_text,
            }
        )
    if len(response.json()["embeddings"]) == 1:

        return response.json()["embeddings"][0]
    
    else:

        return response.json()["embeddings"]

# %%
len(get_ollama_embedding(["1.1.1.1"]))
# Out:
# 1024

# %%
G.nodes['1.1.1.1']["text"]
# Out:
# "Le présent Code règle une matière visée à l'article 39 de la Constitution."

# %%
# 1) Pre-count the "Article" nodes so tqdm knows the total
article_nodes = [
    n for n, d in G.nodes(data=True) if d.get("node_type") == "Article"
]

# First intantiation
article_nodes_dict = dict.fromkeys(article_nodes, None)

#article_node_embeddings_path = os.path.join(BSARD_data_path, 'intermediate', 'article_node_embeddings.pkl')
#
#with open(article_node_embeddings_path, 'rb') as f:
#    article_nodes_dict = pickle.load(f)

article_node_embedding_dict_unscanned = pd.Series([k for k,v in article_nodes_dict.items() if v == None])

tmp_embeddings_list = []

print_go = True

# 2) Progress bar: one tick per generated embedding
for node in tqdm(article_nodes,
                    desc="Generating embeddings",
                    total=len(article_nodes)):      # optional: tqdm can infer it
    
    tmp_embeddings_list.append(node)

    if len(tmp_embeddings_list) < 100:
        continue

    elif len(tmp_embeddings_list) >= 100:

        tmp_texts_list = [G.nodes[i]["text"] for i in tmp_embeddings_list]
    
        embeddings = get_ollama_embedding(tmp_texts_list)

        for i, embedding in enumerate(embeddings):

            article_nodes_dict[tmp_embeddings_list[i]] = embedding

            if print_go:
                print(f"Node {tmp_embeddings_list[i]} embedding generated: \n Text: {tmp_texts_list[i]}, \n Embedding: {embeddings[i]}.")
                print_go = False

        with open(os.path.join(BSARD_data_path, 'intermediate', "article_node_embeddings.pkl"), 'wb') as f:
            pickle.dump(article_nodes_dict, f)

        tmp_embeddings_list = []  # Reset the list after processing

        time.sleep(0.5)  # Optional: to avoid overwhelming the API with requests

# "Leftovers" 
for node in tqdm(list(article_nodes_dict.keys()), desc="Generating embeddings", total=len(list(article_nodes_dict.keys()))):
    if article_nodes_dict[i] is None:
        article_nodes_dict[i] = get_ollama_embedding(G.nodes[i]["text"])
        print(f"Node {i} embedding generated.")
        time.sleep(0.5)

with open(os.path.join(BSARD_data_path, 'intermediate', "article_node_embeddings.pkl"), 'wb') as f:
            pickle.dump(article_nodes_dict, f)
# Out:
# Generating embeddings:   0%|          | 0/22625 [00:00<?, ?it/s]
# Node 1.1.1.1 embedding generated:
#  Text: Le présent Code règle une matière visée à l'article 39 de la Constitution.,
# ...

# %%
# Assign embeddings to the graph nodes

for art_node in article_node_embedding_dict_unscanned:
    G.nodes[art_node]["embedding"] = article_nodes_dict[art_node]

# %%
# 1) Pre-count the "Act" nodes so tqdm knows the total
act_nodes = [
    (n, d) for n, d in G.nodes(data=True) if d.get("node_type") == "Act"
]

# 2) Progress bar: one tick per generated embedding
for node, data in tqdm(act_nodes,
                       desc="Generating embeddings",
                       total=len(act_nodes)):      # optional: tqdm can infer it
    data["embedding"] = get_ollama_embedding(data["act_title"])
    time.sleep(0.5)
# Out:
# Generating embeddings: 100%|██████████| 35/35 [00:25<00:00,  1.38it/s]

# %%
# 1) Embeddings for Title: average of its Articles
title_nodes = [n for n, d in G.nodes(data=True) if d.get("node_type") == "Title"]
for title in tqdm(title_nodes, desc="Aggregating Title embeddings"):
    # extract only Articles with embedding
    child_articles = [
        nbr for nbr in G.successors(title)
        if G.nodes[nbr].get("node_type") == "Article"
           and "embedding" in G.nodes[nbr]
    ]
    if not child_articles:
        continue

    embs = np.stack([G.nodes[art]["embedding"] for art in child_articles])
    G.nodes[title]["embedding"] = embs.mean(axis=0).tolist()


# 2) Embeddings for Book: average of its Articles or Titles
book_nodes = [n for n, d in G.nodes(data=True) if d.get("node_type") == "Book"]
for book in tqdm(book_nodes, desc="Aggregating Book embeddings"):
    # children can be Articles or Titles
    child_embs = []
    for nbr in G.successors(book):
        nt = G.nodes[nbr].get("node_type")
        if ("embedding" in G.nodes[nbr]) and nt in ("Article", "Title"):
            child_embs.append(G.nodes[nbr]["embedding"])

    if not child_embs:
        continue

    embs = np.stack(child_embs)
    G.nodes[book]["embedding"] = embs.mean(axis=0).tolist()


# 3) Embeddings for Act: mix of its own embedding and the average of its neighbors
act_nodes = [n for n, d in G.nodes(data=True) if d.get("node_type") == "Act"]
for act in tqdm(act_nodes, desc="Aggregating Act embeddings"):
    # neighbors with embedding (could be Book or Title depending on your graph)
    nbr_embs = [
        G.nodes[nbr]["embedding"]
        for nbr in G.successors(act)
        if "embedding" in G.nodes[nbr]
    ]
    if not nbr_embs or "embedding" not in G.nodes[act]:
        continue

    nbr_mean = np.stack(nbr_embs).mean(axis=0)
    own_emb  = np.array(G.nodes[act]["embedding"])
    # here we choose weight 0.5/0.5; adjust if you want a different balance
    mixed = (own_emb + nbr_mean) / 2
    G.nodes[act]["embedding"] = mixed.tolist()

# 4) Embeddings for Central node: average of all its neighbors
meta_nodes = [n for n, d in G.nodes(data=True) if d.get("node_type") == "Central Node"]

for meta in tqdm(meta_nodes, desc="Aggregating Meta embeddings"):
    # incoming and outgoing neighbors, without duplicates
    neighs = set(G.successors(meta)).union(G.predecessors(meta))
    neigh_embs = [G.nodes[v]["embedding"] for v in neighs if "embedding" in G.nodes[v]]

    if not neigh_embs:
        continue  # no embeddings available

    embs = np.stack(neigh_embs)
    G.nodes[meta]["embedding"] = embs.mean(axis=0).tolist()
# Out:
# ...
# Aggregating Meta embeddings: 100%|██████████| 1/1 [00:00<00:00, 328.45it/s]

# %%
# Embeddings for KeyTerm nodes

# 1) Pre-count the "KeyTerm" nodes so tqdm knows the total
keyterm_nodes = [
    n for n, d in G.nodes(data=True) if d.get("node_type") == "KeyTerm"
]

# First intantiation
keyterm_nodes_dict = dict.fromkeys(article_nodes, None)

#article_node_embeddings_path = os.path.join(BSARD_data_path, 'intermediate', 'article_node_embeddings.pkl')
#
#with open(article_node_embeddings_path, 'rb') as f:
#    article_nodes_dict = pickle.load(f)

keyterm_node_embedding_dict_unscanned = pd.Series([k for k,v in article_nodes_dict.items() if v == None])

tmp_embeddings_list = []

print_go = True

# 2) Progress bar: one tick per generated embedding
for node in tqdm(article_nodes,
                    desc="Generating embeddings",
                    total=len(article_nodes)):      # optional: tqdm can infer it
    
    tmp_embeddings_list.append(node)

    if len(tmp_embeddings_list) < 100:
        continue

    elif len(tmp_embeddings_list) >= 100:
    
        embeddings = get_ollama_embedding(tmp_embeddings_list)

        for i, embedding in enumerate(embeddings):

            keyterm_nodes_dict[tmp_embeddings_list[i]] = embedding

            if print_go:
                print(f"Node {tmp_embeddings_list[i]} embedding generated: \n Text: {tmp_texts_list[i]}, \n Embedding: {embeddings[i]}.")
                print_go = False


        with open(os.path.join(BSARD_data_path, 'intermediate', "keyterm_node_embeddings.pkl"), 'wb') as f:
            pickle.dump(article_nodes_dict, f)

        tmp_embeddings_list = []  # Reset the list after processing

        time.sleep(0.5)  # Optional: to avoid overwhelming the API with requests

# "Leftovers" 
for i in tqdm(list(keyterm_nodes_dict.keys()), desc="Generating embeddings", total=len(list(keyterm_nodes_dict.keys()))):
    if keyterm_nodes_dict[i] is None:
        keyterm_nodes_dict[i] = get_ollama_embedding(i)
        print(f"Node {i} embedding generated.")
        time.sleep(0.5)

with open(os.path.join(BSARD_data_path, 'intermediate', "keyterm_node_embeddings.pkl"), 'wb') as f:
            pickle.dump(article_nodes_dict, f)

# %%
# Ensure all nodes have an attribute "embedding"
assert all("embedding" in data for _, data in G.nodes(data=True)), "Some nodes lack an embedding!"

# %%
with open(os.path.join(BSARD_data_path, 'hybrid_graph_full_wsem.pkl'), 'wb') as f:
    pickle.dump(G, f)
