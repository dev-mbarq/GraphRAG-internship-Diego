# %% [markdown]
# https://www.bentoml.com/blog/a-guide-to-open-source-embedding-models

# %%
import os
import sys
import json
import pickle
import requests

import networkx as nx
import numpy as np
import pandas as pd
import requests

import pynvml
import time
import subprocess

# Add "src" path to Python path
sys.path.append(os.path.abspath("../src"))

# Import custom embedding function
from embedding_utils import get_ollama_embedding

# %%
def get_gpu_temperature():
    # Run nvidia-smi to query GPU temperature
    result = subprocess.run(
        ["nvidia-smi", "--query-gpu=temperature.gpu", "--format=csv,noheader"],
        stdout=subprocess.PIPE,
        text=True
    )
    # Parse and return temperature of GPU 0
    return int(result.stdout.strip().split('\n')[0])

def gpu_temperature_rest_time():
    if get_gpu_temperature() >= 80:
        return 100
    else:
        return 0

# %%
# Load graph
with open("../data/base_hybrid_graph.pkl", "rb") as f:
    G = pickle.load(f)

# Load corpus
with open("../data/Multi-hop_RAG_dataset/corpus.json", "r", encoding="utf-8") as f:
    corpus = json.load(f)

# Load raw entities (for summary embeddings)
with open('../data/multihop_dataset_raw_entities.pkl', 'rb') as f:
    raw_entities = pickle.load(f)

# Convert corpus data into df
corpus_as_df = pd.DataFrame(corpus)

# %%
# Test embedding generation
embedding = get_ollama_embedding("Embedding generation test", )
print(embedding)
print(len(embedding["embedding"]))
# Out:
# {'embedding': [-1.0566672086715698, -0.9916018843650818, -0.1977226734161377, 0.44412606954574585, -0.07686168700456619, -0.7473859786987305, 0.6320770382881165, -0.3504481613636017, -0.2972276210784912, 0.16000185906887054, -0.5720860362052917, 0.17846082150936127, 0.44752582907676697, 0.3534890413284302, -0.43371647596359253, -0.8164119720458984, -1.5097856521606445, -0.2829397916793823, -0.09882917255163193, -1.298407793045044, 0.010910525918006897, -1.9046603441238403, 0.5234888792037964, -0.5442371368408203, 0.584852933883667, 0.22193007171154022, -0.3788483738899231, -0.46844640374183655, 0.2362867146730423, -0.6325748562812805, 0.6420486569404602, -1.0469647645950317, 0.4750227928161621, -1.4116549491882324, -0.5067553520202637, -0.05261102318763733, -0.37181004881858826, -0.09439092874526978, -1.6463353633880615, -0.0347198061645031, -0.3107561767101288, 0.013417135924100876, 0.7972341179847717, -1.205283761024475, 0.9445411562919617, -0.7153135538101196, 0.156986802816391, -0.6772543787956238, -0.9228314757347107, 0.29295241832733154, 0.49278318881988525, 0.9115105867385864, 0.6189629435539246, 0.14652307331562042, 0.8697314262390137, 1.4166319370269775, 0.05699270963668823, 1.1082687377929688, -1.3613923788070679, -0.7517210841178894, -0.429318368434906, 1.9109346866607666, -0.7986212968826294, 1.5143331289291382, 1.0462744235992432, 0.10071318596601486, -0.21802927553653717, 0.09847413003444672, -0.5936064720153809, -1.158691644668579, -0.2145586609840393, 0.39574870467185974, -0.7612013816833496, 0.5084653496742249, -1.454025149345398, 0.9024823904037476, 0.14280113577842712, -0.5603657364845276, -0.5601381063461304, -0.2672007083892822, 0.2023758441209793, -0.4211300313472748, 0.5941761136054993, -0.08391460031270981, -0.5692784786224365, -0.01109880581498146, -1.3696950674057007, -1.2967548370361328, 0.052186019718647, -0.39484041929244995, -1.5009498596191406, -0.7083991169929504, 0.22347956895828247, -0.8030608892440796, -1.4678393602371216, 0.6101832985877991, -0.10563313961029053, 1.0470781326293945, 0.3201967477798462, 0.4689159691333771, -0.1469241976737976, 0.01577330380678177, -0.3393242061138153, 0.3249964118003845, -0.172127366065979, -0.16473916172981262, 1.0272573232650757, 0.46765124797821045, -0.4409887194633484, -0.46327412128448486, 0.3764612674713135, -0.35961994528770447, -0.5538898706436157, 1.412900447845459, 0.09612260013818741, 0.14804847538471222, -1.6464180946350098, 0.292007178068161, 0.3059011399745941, -0.6029490828514099, 1.0859408378601074, -0.19777196645736694, 2.2030863761901855, -1.2042152881622314, -0.32202455401420593, -1.3552131652832031, 1.0402618646621704, 0.35229814052581787, -0.5837181806564331, -0.8652923107147217, 0.24661219120025635, -0.1960025429725647, -0.8696351051330566, -0.8965314030647278, -0.5656759738922119, -0.13322487473487854, -0.3454652726650238, -0.4013409912586212, 0.23156148195266724, -1.6530705690383911, 0.30310913920402527, -0.2898191511631012, -0.6788011789321899, -1.2139054536819458, 0.09750379621982574, -1.275194764137268, -0.10839381068944931, -0.7753473520278931, 0.8529277443885803, 0.15724551677703857, 0.22641706466674805, 0.47804418206214905, 0.38828951120376587, -0.4406481683254242, 0.33694496750831604, -0.2585202157497406, -0.510585367679596, 0.14668209850788116, 0.9580118060112, 1.4068024158477783, -0.16626007854938507, 0.282176673412323, -0.7716630101203918, -1.1692970991134644, -0.0034689782187342644, 0.1895301192998886, 0.9827601909637451, 0.5578471422195435, -0.2879831790924072, -0.7890294790267944, 1.1572741270065308, 0.8822104334831238, 0.8844230771064758, 0.020462431013584137, 0.2885655462741852, 0.267947793006897, 2.2357404232025146, -0.18908905982971191, 0.17521066963672638, -1.230438470840454, 0.44867122173309326, 0.6196832656860352, -0.17304106056690216, -0.07761511951684952, -0.15993395447731018, -0.4894944131374359, 0.263145387172699, -0.6483089327812195, 0.2899284362792969, 0.7999126315116882, -0.28381460905075073, -1.3149535655975 ...
# 1024

# %%
# Generate and assign embeddings for each chunk in the graph (Expected execution time ~ 6-7min)
for node, data in G.nodes(data=True):
    if data.get("type") == "chunk" and "text" in data:
        data["embedding"] = get_ollama_embedding(data["text"])["embedding"]

# %%
# Generate and assign embeddings for each article in the graph based on the summary 
for node, data in G.nodes(data=True):
    if data.get("type") == "article":
        data["embedding"] = get_ollama_embedding(raw_entities[node]["summary"])["embedding"]
# Out:
# 'Amazon is holding an 11-day shopping event, beginning November 17th and continuing through Cyber Monday, November 27th, with both Black Friday and Cyber Monday deals available. The article highlights deals across various categories including Amazon devices (Echo, Fire TV, Kindle), Apple products, TVs, laptops, headphones, tablets, gaming, speakers, vacuums, kitchen appliances, smart home devices, fitness tech, beauty tech, drones, cameras, Lego, and gift cards. \n\nSpecific deals mentioned include the Echo Show for under $40, the 10th generation 64GB iPad for $349, a 65-inch Fire TV at a record low price, the Microsoft Surface Laptop Go 3 for $599.99, Bose QuietComfort 45 headphones for under $200, and the Meta Quest 2 with a $50 credit. Many deals are marked as all-time lows (🔥) or exclusive to Prime members (📨). The article will be updated continuously as new deals become available.'

# %%
#with open("../data/graph_w_embeddings.pkl", "rb") as f:
#    G = pickle.load(f)

# %% [markdown]
# For this first "test version" of the graph, the base semantic node embedding in the graph will be computed in the following manner:
#
# - __*Chunk embeddings*__: Embedding of the chunk itself
# - __*Article embeddings*__: Average of the article summary embedding and the avergae of all chunk embeddings within the article
# - __*Author embeddings*__: Average of all article embeddings of articles written by the author
# - __*Category embeddings*__: Average of all article embeddings comprised within the category
# - __*Source embedding*__: Average of all article embeddings published by the source
# - __*Entity_LOC embedding*__:
# - __*Entity_PER embedding*__:
# - __*Entity_ORG embedding*__:

# %% [markdown]
# ### Entity embeddings

# %%
# Find all nodes with type "Entity_LOC"
entity_nodes = [node.split("_") for node in G.nodes() if G.nodes[node]['type'] in ['entity_PER', 'entity_LOC', 'entity_ORG']]

#print("\n=== LOCATION ENTITIES ===")
#print(f"Found {len(loc_entities)} location entities:")
#for entity in loc_entities:
#    print(f"- {entity}")

ent_type_mapping ={"ORG":"Organization", "LOC":"Location", "PER":"Person"} 

response_tracking = {}

for i, entity_node in enumerate(entity_nodes):
    # Print progress
    print(f"Processing {entity_node[0]} ({i+1}/{len(entity_nodes)} - {((i+1)/len(entity_nodes)*100):.1f}%)")

    # Check GPU temperature and wait if necessary 
    while gpu_temperature_rest_time() != 0:
        print(f"== Pausing code execution to cool down GPU... ({get_gpu_temperature()}) ==")
        time.sleep(gpu_temperature_rest_time())
    
    # Get entity name and type
    entity_name = entity_node[0]
    entity_type = entity_node[1]

    prompt = f"""
    {entity_name} is an entity of type {entity_type} extracted from a text by an NER algorithm. 
    Your task is to assess withouth further context whether this entity is widely recognizable and return your answer in a JSON format. 
    In this JSON first provide again {entity_name} in the field "entity name" and then {ent_type_mapping[entity_type]}  in the field "entity_type"
    Finally, in the filed "widely_recognizable" indicate with a boolean value your decision about whether this is a widely recognizable entity without further context.
    Additionally, if you determine this entity is widely recognizable, provide one short sentence of context about this entity in the field "short_context", otherwise leave it blank.
    As a final remark, consider that these entites has been extracted from a corpus of news articles covering topics in Science, Business, Entertainment, Sports, Technology and Health.
    It is very unlikely that widely recognizable entities of the type "organization" or "person" unrelated to these domains appear in the corpus.
    """
    url = "http://localhost:11434/api/chat"
    headers = {"Content-Type": "application/json"}

    data = {
        "model": "gemma3:27b-it-q8_0",
        "messages": [{"role": "user", "content": prompt}],
        "stream": False,
        "format": {
            "type": "object",
            "properties": {
                "entity_name": {"type": "string"},
                "entity_type": {"type": "string"},
                "widely_recognizable": {"type" : "boolean"},
                "short_context":{"type": "string"}  
                }
            },
            "required": ["entity_name", "entity_type", "widely_recognizable", "short_context"]
        }


    response = requests.post(url, headers=headers, data=json.dumps(data))

    response_json =json.loads(response.json()['message']['content'])

    print(response.json()['message']['content']) # CEGAR

    # If the entity is widely recognizable, use the short context to generate an embedding
    if response_json["widely_recognizable"]:
        entity_base_embedding = get_ollama_embedding(response_json["short_context"])["embedding"]
        response_json["embedding"] = entity_base_embedding
        # Assign the embedding to the entity node
        G.nodes[f"{entity_node[0]}_{entity_node[1]}"]["embedding"] = entity_base_embedding
        print(f"---> SUCCESS: Entity {entity_node[0]} ({entity_node[1]}) is widely recognizable. Embedding assigned.")
    else:
        # Create default zero embedding for non-recognizable entities
        default_embedding = np.zeros(1024, dtype=np.float32)
        response_json["embedding"] = default_embedding
        # Assign the default embedding to the entity node
        G.nodes[f"{entity_node[0]}_{entity_node[1]}"]["embedding"] = default_embedding
        print(f"---> DEFAULT EMBEDDING: Entity {entity_node[0]} ({entity_node[1]}) is not widely recognizable. Default embedding assigned.")
    response_tracking[f"{entity_node[0]}_{entity_node[1]}"]  = response_json


# Save response_tracking to pickle file
#with open('../data/response_tracking.pkl', 'wb') as f:
#    pickle.dump(response_tracking, f)
#print("Saved!")

# Mostrar el resultado
#print(response.status_code)
#print(response.json())
#print(response.json()['message']['content'])
# Out:
# Processing Amazon (1/743 - 0.1%)
# {
#   "entity_name": "Amazon",
#   "entity_type": "ORG",
#   "widely_recognizable": true,
#   "short_context": "Amazon is a multinational technology company best known for e-commerce, cloud computing, and digital streaming."
# }
#
# ---> SUCCESS: Entity Amazon (ORG) is widely recognizable. Embedding assigned.
# Processing Apple (2/743 - 0.3%)
# {
#   "entity_name": "Apple",
#   "entity_type": "ORG",
#   "widely_recognizable": true,
#   "short_context": "Apple is a multinational technology company known for designing, developing, and selling consumer electronics, computer software, and online services."
# }
#
# ---> SUCCESS: Entity Apple (ORG) is widely recognizable. Embedding assigned.
# Processing Bendigo (3/743 - 0.4%)
# {
#   "entity_name": "Bendigo",
#   "entity_type": "ORG",
#   "widely_recognizable": true,
#   "short_context": "Bendigo is a city in Victoria, Australia, known for its gold rush history and art galleries."
# }
#
# ---> SUCCESS: Entity Bendigo (ORG) is widely recognizable. Embedding assigned.
# Processing Adelaide Bank (4/743 - 0.5%)
# {
#   "entity_name": "Adelaide Bank",
#   "entity_type": "Organization",
#   "widely_recognizable": true,
#   "short_context": "Adelaide Bank is an Australian financial institution providing banking and financial services."
# }
#
# ---> SUCCESS: Entity Adelaide Bank (ORG) is widely recognizable. Embedding assigned.
# Processing Wall Street (5/743 - 0.7%)
# {
#   "entity_name": "Wall Street",
#   "entity_type": "LOC",
#   "widely_recognizable": true,
#   "short_context": "Wall Street is a globally recognized center for financial markets and is often used as a metonym for the U.S. financial industry."
# }
#
# ---> SUCCESS: Entity Wall Street (LOC) is widely recognizable. Embedding assigned.
# Processing Dow Jones (6/743 - 0.8%)
# {
#   "entity_name": "Dow Jones",
#   "entity_type": "Organization",
#   "widely_recognizable": true,
#   "short_context": "Dow Jones is a financial news and information provider, and the publisher of The Wall Street Journal."
# }
#
# ---> SUCCESS: Entity Dow Jones (ORG) is widely recognizable. Embedding assigned.
# Processing US (7/743 - 0.9%)
# {
#   "entity_name": "US",
#   "entity_type": "Organization",
#   "widely_recognizable": true,
#   "short_context": "US is a common abbreviation for the United States of America, a country frequently discussed in news across all domains."
# }
#
# ---> SUCCESS: Entity US (ORG) is widely recognizable. Embedding assigned.
# Processing UAW (8/743 - 1.1%)
# {
#   "entity_name": "UAW",
#   "entity_type": "Organization",
#   "widely_recognizable": true,
#   "short_context": "The UAW (United Auto Workers) is a major labor union representing workers in the automotive industry."
# }
#
# ---> SUCCESS: Entity UAW (ORG) is widely recognizable. Embedding assigned.
# Processing France (9/743 - 1.2%)
# {
#   "entity_name": "France",
#   "entity_type": "LOC",
#   "widely_recognizable": true,
#   "short_context": "France is a country in Western Europe, known for its culture, cuisine, and historical landmarks."
# }
#
# ---> SUCCESS: Entity France (LOC) is widely recognizable. Embedding assigned.
# Processing Germany (10/743 - 1.3%)
# {
#   "entity_name": "Germany",
#   "entity_type": "LOC",
#   "widely_recognizable": true,
#   "short_context": "Germany is a country in Central Europe known for its history, automotive industry, and contributions to science and technology."
# }
#
# ---> SUCCESS: Entity Germany (LOC) is widely recognizable. Embedding assigned.
# Processing Qantas (11/743 - 1.5%)
# {
#   "entity_name": "Qantas",
#   "entity_type": "Organization",
#   "widely_recognizable": true,
#   "short_context": "Qantas is the flag carrier airline of Australia and a major player in the global aviation industry."
# }
#
# ---> SUCCESS: Entity Qantas (ORG) is widely recognizable. Embedding assigned.
# Processing Senate (12/743 - 1.6%)
# {
#   "entity_name": "Senate",
#   "entity_type": "Organization",
#   "widely_recognizable": true,
#   "short_context": "The Senate is one of the two chambers of the U.S. Congress, responsible for making laws."
# }
#
# ---> SUCCESS: Entity Senate (ORG) is widely recognizable. Embedding assigned.
# Processing Federal Trade Commission (13/743 - 1.7%)
# {
#   "entity_name": "Federal Trade Commission",
#   "entity_type": "Organization",
#   "widely_recognizable": true,
#   "short_context": "The Federal Trade Commission is a US government agency that protects consumers and promotes competition."
# }
#
# ---> SUCCESS: Entity Federal Trade Commission (ORG) is widely recognizable. Embedding assigned.
# Processing F (14/743 - 1.9%)
# {"entity_name": "F", "entity_type": "Organization", "widely_recognizable": false, "short_context": ""}
#
# ---> DEFAULT EMBEDDING: Entity F (ORG) is not widely recognizable. Default embedding assigned.
# Processing FTC (15/743 - 2.0%)
# {
#   "entity_name": "FTC",
#   "entity_type": "Organization",
#   "widely_recognizable": true,
#   "short_context": "The FTC (Federal Trade Commission) is a US government agency that protects consumers and promotes competition."
# }
#
# ---> SUCCESS: Entity FTC (ORG) is widely recognizable. Embedding assigned.
# Processing NFL (16/743 - 2.2%)
# {
#   "entity_name": "NFL",
#   "entity_type": "Organization",
#   "widely_recognizable": true,
#   "short_context": "The NFL is the professional American football league in the United States."
# }
#
# ---> SUCCESS: Entity NFL (ORG) is widely recognizable. Embedding assigned.
# Processing Raiders (17/743 - 2.3%)
# {
#   "entity_name": "Raiders",
#   "entity_type": "ORG",
#   "widely_recognizable": true,
#   "short_context": "The Raiders are a professional American football team based in Las Vegas, Nevada, and a member of the National Football League (NFL)."
# }
#
# ---> SUCCESS: Entity Raiders (ORG) is widely recognizable. Embedding assigned.
# Processing Chiefs (18/743 - 2.4%)
# {
#   "entity_name": "Chiefs",
#   "entity_type": "Organization",
#   "widely_recognizable": true,
#   "short_context": "The Kansas City Chiefs are a professional American football team based in Kansas City, Missouri."
# }
#
# ---> SUCCESS: Entity Chiefs (ORG) is widely recognizable. Embedding assigned.
# Processing Giants (19/743 - 2.6%)
# {
#   "entity_name": "Giants",
#   "entity_type": "Organization",
#   "widely_recognizable": true,
#   "short_context": "The Giants typically refers to the New York Giants, a professional American football team."
# }
#
# ---> SUCCESS: Entity Giants (ORG) is widely recognizable. Embedding assigned.
# Processing Eagles (20/743 - 2.7%)
# {
#   "entity_name": "Eagles",
#   "entity_type": "Organization",
#   "widely_recognizable": true,
#   "short_context": "The Philadelphia Eagles are a professional American football team based in Philadelphia."
# }
#
# ---> SUCCESS: Entity Eagles (ORG) is widely recognizable. Embedding assigned.
# Processing Ravens (21/743 - 2.8%)
# {
#   "entity_name": "Ravens",
#   "entity_type": "Organization",
#   "widely_recognizable": true,
#   "short_context": "The Baltimore Ravens are a professional American football team based in Baltimore, Maryland."
# }
#
# ---> SUCCESS: Entity Ravens (ORG) is widely recognizable. Embedding assigned.
# Processing 49ers (22/743 - 3.0%)
# {
#   "entity_name": "49ers",
#   "entity_type": "Organization",
#   "widely_recognizable": true,
#   "short_context": "The 49ers are a professional American football team based in the San Francisco Bay Area."
# }
#
# ---> SUCCESS: Entity 49ers (ORG) is widely recognizable. Embedding assigned.
# Processing Patrick Mahomes (23/743 - 3.1%)
# {
#   "entity_name": "Patrick Mahomes",
#   "entity_type": "Person",
#   "widely_recognizable": true,
#   "short_context": "Patrick Mahomes is a professional American football quarterback for the Kansas City Chiefs and a prominent figure in the NFL."
# }
#
# ---> SUCCESS: Entity Patrick Mahomes (PER) is widely recognizable. Embedding assigned.
# Processing Maxx Crosby (24/743 - 3.2%)
# {
#   "entity_name": "Maxx Crosby",
#   "entity_type": "Person",
#   "widely_recognizable": true,
#   "short_context": "Maxx Crosby is a professional American football defensive end for the Las Vegas Raiders in the NFL."
# }
#
# ---> SUCCESS: Entity Maxx Crosby (PER) is widely recognizable. Embedding assigned.
# Processing Travis Kelce (25/743 - 3.4%)
# {
#   "entity_name": "Travis Kelce",
#   "entity_type": "Person",
#   "widely_recognizable": true,
#   "short_context": "Travis Kelce is a professional American football tight end for the Kansas City Chiefs and is widely known for his athletic achievements and high-profile relationship."
# }
#
# ---> SUCCESS: Entity Travis Kelce (PER) is widely recognizable. Embedding assigned.
# Processing Taylor Swift (26/743 - 3.5%)
# {
#   "entity_name": "Taylor Swift",
#   "entity_type": "Person",
#   "widely_recognizable": true,
#   "short_context": "Taylor Swift is a highly successful and globally recognized American singer-songwriter."
# }
#
# ---> SUCCESS: Entity Taylor Swift (PER) is widely recognizable. Embedding assigned.
# Processing Philadelphia (27/743 - 3.6%)
# {
#   "entity_name": "Philadelphia",
#   "entity_type": "ORG",
#   "widely_recognizable": true,
#   "short_context": "Philadelphia is a major city in Pennsylvania, known for its history, culture, and sports teams."
# }
#
# ---> SUCCESS: Entity Philadelphia (ORG) is widely recognizable. Embedding assigned.
# Processing Brock Purdy (28/743 - 3.8%)
# {
#   "entity_name": "Brock Purdy",
#   "entity_type": "Person",
#   "widely_recognizable": true,
#   "short_context": "Brock Purdy is a professional American football quarterback for the San Francisco 49ers in the NFL."
# }
#
# ---> SUCCESS: Entity Brock Purdy (PER) is widely recognizable. Embedding assigned.
# Processing Lamar Jackson (29/743 - 3.9%)
# {
#   "entity_name": "Lamar Jackson",
#   "entity_type": "Person",
#   "widely_recognizable": true,
#   "short_context": "Lamar Jackson is a prominent NFL quarterback for the Baltimore Ravens."
# }
#
# ---> SUCCESS: Entity Lamar Jackson (PER) is widely recognizable. Embedding assigned.
# Processing Christian McCaffrey (30/743 - 4.0%)
# {
#   "entity_name": "Christian McCaffrey",
#   "entity_type": "Person",
#   "widely_recognizable": true,
#   "short_context": "Christian McCaffrey is a prominent American football running back currently playing for the San Francisco 49ers."
# }
#
# ---> SUCCESS: Entity Christian McCaffrey (PER) is widely recognizable. Embedding assigned.
# Processing Josh Jacobs (31/743 - 4.2%)
# {
#   "entity_name": "Josh Jacobs",
#   "entity_type": "Person",
#   "widely_recognizable": true,
#   "short_context": "Josh Jacobs is a professional American football running back for the Las Vegas Raiders in the NFL."
# }
#
# ---> SUCCESS: Entity Josh Jacobs (PER) is widely recognizable. Embedding assigned.
# Processing Lions (32/743 - 4.3%)
# {
#   "entity_name": "Lions",
#   "entity_type": "Organization",
#   "widely_recognizable": true,
#   "short_context": "The Detroit Lions are a professional American football team based in Detroit, Michigan."
# }
#
# ---> SUCCESS: Entity Lions (ORG) is widely recognizable. Embedding assigned.
# Processing Aidan O ' Connell (33/743 - 4.4%)
# {
#   "entity_name": "Aidan O'Connell",
#   "entity_type": "Person",
#   "widely_recognizable": true,
#   "short_context": "Aidan O'Connell is an American football quarterback for the Las Vegas Raiders in the NFL."
# }
#
# ---> SUCCESS: Entity Aidan O ' Connell (PER) is widely recognizable. Embedding assigned.
# Processing Sam LaPorta (34/743 - 4.6%)
# {
#   "entity_name": "Sam LaPorta",
#   "entity_type": "Person",
#   "widely_recognizable": true,
#   "short_context": "Sam LaPorta is a tight end for the Detroit Lions in the National Football League."
# }
#
# ---> SUCCESS: Entity Sam LaPorta (PER) is widely recognizable. Embedding assigned.
# Processing Jahmyr Gibbs (35/743 - 4.7%)
# {
#   "entity_name": "Jahmyr Gibbs",
#   "entity_type": "Person",
#   "widely_recognizable": true,
#   "short_context": "Jahmyr Gibbs is a professional American football running back for the Detroit Lions."
# }
#
# ---> SUCCESS: Entity Jahmyr Gibbs (PER) is widely recognizable. Embedding assigned.
# Processing Gibbs (36/743 - 4.8%)
# {
#   "entity_name": "Gibbs",
#   "entity_type": "Person",
#   "widely_recognizable": true,
#   "short_context": "Josiah Willard Gibbs was a prominent American scientist who made significant contributions to thermodynamics, statistical mechanics, and vector calculus."
# }
#
# ---> SUCCESS: Entity Gibbs (PER) is widely recognizable. Embedding assigned.
# Processing Houston Astros (37/743 - 5.0%)
# {
#   "entity_name": "Houston Astros",
#   "entity_type": "Organization",
#   "widely_recognizable": true,
#   "short_context": "The Houston Astros are a professional baseball team based in Houston, Texas, and are a member of Major League Baseball."
# }
#
# ---> SUCCESS: Entity Houston Astros (ORG) is widely recognizable. Embedding assigned.
# Processing MLB (38/743 - 5.1%)
# {
#   "entity_name": "MLB",
#   "entity_type": "Organization",
#   "widely_recognizable": true,
#   "short_context": "MLB stands for Major League Baseball, the professional baseball league in North America."
# }
#
# ---> SUCCESS: Entity MLB (ORG) is widely recognizable. Embedding assigned.
# Processing Astros (39/743 - 5.2%)
# {
#   "entity_name": "Astros",
#   "entity_type": "Organization",
#   "widely_recognizable": true,
#   "short_context": "The Astros are a professional baseball team based in Houston, Texas, and are a member of Major League Baseball."
# }
#
# ---> SUCCESS: Entity Astros (ORG) is widely recognizable. Embedding assigned.
# Processing Dodgers (40/743 - 5.4%)
# {
#   "entity_name": "Dodgers",
#   "entity_type": "Organization",
#   "widely_recognizable": true,
#   "short_context": "The Los Angeles Dodgers are a professional baseball team based in Los Angeles, California."
# }
#
# ---> SUCCESS: Entity Dodgers (ORG) is widely recognizable. Embedding assigned.
# Processing Arizona Diamondbacks (41/743 - 5.5%)
# {
#   "entity_name": "Arizona Diamondbacks",
#   "entity_type": "Organization",
#   "widely_recognizable": true,
#   "short_context": "The Arizona Diamondbacks are a professional baseball team based in Phoenix, Arizona, and a member of Major League Baseball."
# }
#
# ---> SUCCESS: Entity Arizona Diamondbacks (ORG) is widely recognizable. Embedding assigned.
# Processing Chase Field (42/743 - 5.7%)
# {
#   "entity_name": "Chase Field",
#   "entity_type": "LOC",
#   "widely_recognizable": true,
#   "short_context": "Chase Field is a baseball stadium in Phoenix, Arizona, home to the Arizona Diamondbacks."
# }
#
# ---> SUCCESS: Entity Chase Field (LOC) is widely recognizable. Embedding assigned.
# Processing Phillies (43/743 - 5.8%)
# {
#   "entity_name": "Phillies",
#   "entity_type": "Organization",
#   "widely_recognizable": true,
#   "short_context": "The Phillies are a professional baseball team based in Philadelphia, Pennsylvania."
# }
#
# ---> SUCCESS: Entity Phillies (ORG) is widely recognizable. Embedding assigned.
# Processing Bryce Harper (44/743 - 5.9%)
# {
#   "entity_name": "Bryce Harper",
#   "entity_type": "Person",
#   "widely_recognizable": true,
#   "short_context": "Bryce Harper is a professional baseball player for the Philadelphia Phillies, known for his powerful hitting and charismatic personality."
# }
#
# ---> SUCCESS: Entity Bryce Harper (PER) is widely recognizable. Embedding assigned.
# Processing Los Angeles Dodgers (45/743 - 6.1%)
# {
#   "entity_name": "Los Angeles Dodgers",
#   "entity_type": "Organization",
#   "widely_recognizable": true,
#   "short_context": "The Los Angeles Dodgers are a professional baseball team based in Los Angeles, California, and are a prominent franchise in Major League Baseball."
# }
#
# ---> SUCCESS: Entity Los Angeles Dodgers (ORG) is widely recognizable. Embedding assigned.
# Processing A (46/743 - 6.2%)
# {"entity_name": "A", "entity_type": "Organization", "widely_recognizable": false, "short_context": ""}
#
# ---> DEFAULT EMBEDDING: Entity A (ORG) is not widely recognizable. Default embedding assigned.
# Processing Sam Bankman - Fried (47/743 - 6.3%)
# {
#   "entity_name": "Sam Bankman - Fried",
#   "entity_type": "Person",
#   "widely_recognizable": true,
#   "short_context": "Sam Bankman-Fried is the founder and former CEO of the cryptocurrency exchange FTX, who was convicted of fraud and conspiracy charges."
# }
#
# ---> SUCCESS: Entity Sam Bankman - Fried (PER) is widely recognizable. Embedding assigned.
# Processing SBF (48/743 - 6.5%)
# {
#   "entity_name": "SBF",
#   "entity_type": "Organization",
#   "widely_recognizable": true,
#   "short_context": "SBF refers to Sam Bankman-Fried, the founder of the cryptocurrency exchange FTX, who was involved in a high-profile fraud case."
# }
#
# ---> SUCCESS: Entity SBF (ORG) is widely recognizable. Embedding assigned.
# Processing FTX (49/743 - 6.6%)
# {
#   "entity_name": "FTX",
#   "entity_type": "Organization",
#   "widely_recognizable": true,
#   "short_context": "FTX was a cryptocurrency exchange that filed for bankruptcy in November 2022 following allegations of fraud."
# }
#
# ---> SUCCESS: Entity FTX (ORG) is widely recognizable. Embedding assigned.
# Processing Alameda Research (50/743 - 6.7%)
# {
#   "entity_name": "Alameda Research",
#   "entity_type": "Organization",
#   "widely_recognizable": true,
#   "short_context": "Alameda Research was a quantitative trading firm founded by Sam Bankman-Fried and played a central role in the collapse of FTX."
# }
#
# ---> SUCCESS: Entity Alameda Research (ORG) is widely recognizable. Embedding assigned.
# Processing Caroline Ellison (51/743 - 6.9%)
# {
#   "entity_name": "Caroline Ellison",
#   "entity_type": "Person",
#   "widely_recognizable": true,
#   "short_context": "Caroline Ellison is a former CEO of Alameda Research and was a key figure in the FTX cryptocurrency exchange collapse."
# }
#
# ---> SUCCESS: Entity Caroline Ellison (PER) is widely recognizable. Embedding assigned.
# Processing Gary Wang (52/743 - 7.0%)
# {
#   "entity_name": "Gary Wang",
#   "entity_type": "Person",
#   "widely_recognizable": true,
#   "short_context": "Gary Wang is a co-founder of the cryptocurrency exchange FTX, and played a key role in its collapse and subsequent legal proceedings."
# }
#
# ---> SUCCESS: Entity Gary Wang (PER) is widely recognizable. Embedding assigned.
# Processing Alameda (53/743 - 7.1%)
# {
#   "entity_name": "Alameda",
#   "entity_type": "ORG",
#   "widely_recognizable": true,
#   "short_context": "Alameda is a city in California, often associated with the tech industry due to its proximity to Silicon Valley."
# }
#
# ---> SUCCESS: Entity Alameda (ORG) is widely recognizable. Embedding assigned.
# Processing Sam Bankman (54/743 - 7.3%)
# {
#   "entity_name": "Sam Bankman",
#   "entity_type": "Person",
#   "widely_recognizable": true,
#   "short_context": "Sam Bankman-Fried is the founder and former CEO of the cryptocurrency exchange FTX, who was convicted of fraud and conspiracy."
# }
#
# ---> SUCCESS: Entity Sam Bankman (PER) is widely recognizable. Embedding assigned.
# Processing Fried (55/743 - 7.4%)
# {"entity_name": "Fried", "entity_type": "PER", "widely_recognizable": false, "short_context": ""}
#
# ---> DEFAULT EMBEDDING: Entity Fried (PER) is not widely recognizable. Default embedding assigned.
# Processing FTT (56/743 - 7.5%)
# {"entity_name": "FTT", "entity_type": "Organization", "widely_recognizable": true, "short_context": "FTT was a cryptocurrency exchange that collapsed in November 2022, leading to significant market disruption."}
#
# ---> SUCCESS: Entity FTT (ORG) is widely recognizable. Embedding assigned.
# Processing Binance (57/743 - 7.7%)
# {
#   "entity_name": "Binance",
#   "entity_type": "ORG",
#   "widely_recognizable": true,
#   "short_context": "Binance is a popular cryptocurrency exchange known for its high trading volumes and wide range of digital assets."
# }
#
# ---> SUCCESS: Entity Binance (ORG) is widely recognizable. Embedding assigned.
# Processing U. S. (58/743 - 7.8%)
# {
#   "entity_name": "U. S.",
#   "entity_type": "LOC",
#   "widely_recognizable": true,
#   "short_context": "U.S. is a common abbreviation for the United States of America, a country frequently discussed in news across all domains."
# }
#
# ---> SUCCESS: Entity U. S. (LOC) is widely recognizable. Embedding assigned.
# Processing BlockFi (59/743 - 7.9%)
# {
#   "entity_name": "BlockFi",
#   "entity_type": "ORG",
#   "widely_recognizable": true,
#   "short_context": "BlockFi was a cryptocurrency lending platform that filed for bankruptcy in 2022."
# }
#
# ---> SUCCESS: Entity BlockFi (ORG) is widely recognizable. Embedding assigned.
# Processing Sam Altman (60/743 - 8.1%)
# {
#   "entity_name": "Sam Altman",
#   "entity_type": "Person",
#   "widely_recognizable": true,
#   "short_context": "Sam Altman is the CEO of OpenAI, the company behind ChatGPT and other AI technologies."
# }
#
# ---> SUCCESS: Entity Sam Altman (PER) is widely recognizable. Embedding assigned.
# Processing Google (61/743 - 8.2%)
# {
#   "entity_name": "Google",
#   "entity_type": "Organization",
#   "widely_recognizable": true,
#   "short_context": "Google is a multinational technology company specializing in internet-related services and products."
# }
#
# ---> SUCCESS: Entity Google (ORG) is widely recognizable. Embedding assigned.
# Processing Flexport (62/743 - 8.3%)
# == Pausing code execution to cool down GPU... (79) ==
# {
#   "entity_name": "Flexport",
#   "entity_type": "Organization",
#   "widely_recognizable": true,
#   "short_context": "Flexport is a modern freight forwarder and platform for global logistics, known for its technology-driven approach to supply chain management."
# }
#
# ---> SUCCESS: Entity Flexport (ORG) is widely recognizable. Embedding assigned.
# Processing Dave Clark (63/743 - 8.5%)
# == Pausing code execution to cool down GPU... (80) ==
# {
#   "entity_name": "Dave Clark",
#   "entity_type": "Person",
#   "widely_recognizable": true,
#   "short_context": "Dave Clark is a former Senior Vice President of Retail at Walmart and previously held a leadership role at Amazon."
# }
#
# ---> SUCCESS: Entity Dave Clark (PER) is widely recognizable. Embedding assigned.
# Processing Michael Lewis (64/743 - 8.6%)
# == Pausing code execution to cool down GPU... (80) ==
# {
#   "entity_name": "Michael Lewis",
#   "entity_type": "Person",
#   "widely_recognizable": true,
#   "short_context": "Michael Lewis is a well-known author and financial journalist, famous for books like *The Big Short* and *Moneyball*."
# }
#
# ---> SUCCESS: Entity Michael Lewis (PER) is widely recognizable. Embedding assigned.
# Processing Donald Trump (65/743 - 8.7%)
# == Pausing code execution to cool down GPU... (80) ==
# {
#   "entity_name": "Donald Trump",
#   "entity_type": "Person",
#   "widely_recognizable": true,
#   "short_context": "Donald Trump is a former President of the United States."
# }
#
# ---> SUCCESS: Entity Donald Trump (PER) is widely recognizable. Embedding assigned.
# Processing TikTok (66/743 - 8.9%)
# {
#   "entity_name": "TikTok",
#   "entity_type": "ORG",
#   "widely_recognizable": true,
#   "short_context": "TikTok is a popular social media platform known for short-form videos."
# }
#
# ---> SUCCESS: Entity TikTok (ORG) is widely recognizable. Embedding assigned.
# Processing Manchester United (67/743 - 9.0%)
# {
#   "entity_name": "Manchester United",
#   "entity_type": "ORG",
#   "widely_recognizable": true,
#   "short_context": "Manchester United is a professional football club based in England, widely considered one of the most successful and popular sports teams globally."
# }
#
# ---> SUCCESS: Entity Manchester United (ORG) is widely recognizable. Embedding assigned.
# Processing Galatasaray (68/743 - 9.2%)
# {
#   "entity_name": "Galatasaray",
#   "entity_type": "Organization",
#   "widely_recognizable": true,
#   "short_context": "Galatasaray is a major Turkish professional football club based in Istanbul."
# }
#
# ---> SUCCESS: Entity Galatasaray (ORG) is widely recognizable. Embedding assigned.
# Processing United (69/743 - 9.3%)
# {
#   "entity_name": "United",
#   "entity_type": "Organization",
#   "widely_recognizable": true,
#   "short_context": "United Airlines is a major American airline headquartered in Chicago."
# }
#
# ---> SUCCESS: Entity United (ORG) is widely recognizable. Embedding assigned.
# Processing Bayern Munich (70/743 - 9.4%)
# {
#   "entity_name": "Bayern Munich",
#   "entity_type": "Organization",
#   "widely_recognizable": true,
#   "short_context": "Bayern Munich is a professional German football club based in Munich, widely considered one of the most successful clubs in the world."
# }
#
# ---> SUCCESS: Entity Bayern Munich (ORG) is widely recognizable. Embedding assigned.
# Processing FC Copenhagen (71/743 - 9.6%)
# {
#   "entity_name": "FC Copenhagen",
#   "entity_type": "Organization",
#   "widely_recognizable": true,
#   "short_context": "FC Copenhagen is a professional football club based in Copenhagen, Denmark, and a prominent team in Scandinavian football."
# }
#
# ---> SUCCESS: Entity FC Copenhagen (ORG) is widely recognizable. Embedding assigned.
# Processing Bruno Fernandes (72/743 - 9.7%)
# {
#   "entity_name": "Bruno Fernandes",
#   "entity_type": "Person",
#   "widely_recognizable": true,
#   "short_context": "Bruno Fernandes is a professional footballer who plays as a midfielder for Manchester United and the Portugal national team."
# }
#
# ---> SUCCESS: Entity Bruno Fernandes (PER) is widely recognizable. Embedding assigned.
# Processing Erik ten Hag (73/743 - 9.8%)
# {
#   "entity_name": "Erik ten Hag",
#   "entity_type": "Person",
#   "widely_recognizable": true,
#   "short_context": "Erik ten Hag is a Dutch professional football coach and former player, currently managing Manchester United."
# }
#
# ---> SUCCESS: Entity Erik ten Hag (PER) is widely recognizable. Embedding assigned.
# Processing Alejandro Garnacho (74/743 - 10.0%)
# {
#   "entity_name": "Alejandro Garnacho",
#   "entity_type": "Person",
#   "widely_recognizable": true,
#   "short_context": "Alejandro Garnacho is a professional footballer who plays as a winger for Manchester United and the Argentina national team."
# }
#
# ---> SUCCESS: Entity Alejandro Garnacho (PER) is widely recognizable. Embedding assigned.
# Processing US (75/743 - 10.1%)
# {
#   "entity_name": "US",
#   "entity_type": "LOC",
#   "widely_recognizable": true,
#   "short_context": "US is a common abbreviation for the United States of America, a country frequently discussed in news across all domains."
# }
#
# ---> SUCCESS: Entity US (LOC) is widely recognizable. Embedding assigned.
# Processing Department of Justice (76/743 - 10.2%)
# {
#   "entity_name": "Department of Justice",
#   "entity_type": "Organization",
#   "widely_recognizable": true,
#   "short_context": "The Department of Justice is a federal executive department of the U.S. government responsible for the enforcement of law and administration of justice."
# }
#
# ---> SUCCESS: Entity Department of Justice (ORG) is widely recognizable. Embedding assigned.
# Processing Mozilla (77/743 - 10.4%)
# {
#   "entity_name": "Mozilla",
#   "entity_type": "Organization",
#   "widely_recognizable": true,
#   "short_context": "Mozilla is a well-known organization famous for developing the Firefox web browser and advocating for an open web."
# }
#
# ---> SUCCESS: Entity Mozilla (ORG) is widely recognizable. Embedding assigned.
# Processing Jada Pinkett Smith (78/743 - 10.5%)
# {
#   "entity_name": "Jada Pinkett Smith",
#   "entity_type": "Person",
#   "widely_recognizable": true,
#   "short_context": "Jada Pinkett Smith is a well-known actress, talk show host, and businesswoman, famous for roles in films like 'The Matrix' and her Facebook Watch talk show 'Red Table Talk'."
# }
#
# ---> SUCCESS: Entity Jada Pinkett Smith (PER) is widely recognizable. Embedding assigned.
# Processing Will Smith (79/743 - 10.6%)
# {
#   "entity_name": "Will Smith",
#   "entity_type": "Person",
#   "widely_recognizable": true,
#   "short_context": "Will Smith is a highly successful American actor, rapper, and producer known for roles in films like 'The Fresh Prince of Bel-Air' and 'Men in Black'."
# }
#
# ---> SUCCESS: Entity Will Smith (PER) is widely recognizable. Embedding assigned.
# Processing Jada (80/743 - 10.8%)
# {
#   "entity_name": "Jada",
#   "entity_type": "Person",
#   "widely_recognizable": true,
#   "short_context": "Jada Pinkett Smith is a well-known actress, talk show host, and businesswoman."
# }
#
# ---> SUCCESS: Entity Jada (PER) is widely recognizable. Embedding assigned.
# Processing Will (81/743 - 10.9%)
# {"entity_name": "Will", "entity_type": "Person", "widely_recognizable": true, "short_context": "Will Smith is a famous American actor and rapper."}
#
# ---> SUCCESS: Entity Will (PER) is widely recognizable. Embedding assigned.
# Processing Kansas City Chiefs (82/743 - 11.0%)
# {
#   "entity_name": "Kansas City Chiefs",
#   "entity_type": "Organization",
#   "widely_recognizable": true,
#   "short_context": "The Kansas City Chiefs are a professional American football team based in Kansas City, Missouri, and are members of the National Football League (NFL)."
# }
#
# ---> SUCCESS: Entity Kansas City Chiefs (ORG) is widely recognizable. Embedding assigned.
# Processing Swift (83/743 - 11.2%)
# {"entity_name": "Swift", "entity_type": "Person", "widely_recognizable": true, "short_context": "Taylor Swift is a globally recognized singer-songwriter."}
#
# ---> SUCCESS: Entity Swift (PER) is widely recognizable. Embedding assigned.
# Processing Kelce (84/743 - 11.3%)
# {
#   "entity_name": "Kelce",
#   "entity_type": "Person",
#   "widely_recognizable": true,
#   "short_context": "Travis Kelce is a widely known American football tight end for the Kansas City Chiefs."
# }
#
# ---> SUCCESS: Entity Kelce (PER) is widely recognizable. Embedding assigned.
# Processing South Africa (85/743 - 11.4%)
# {
#   "entity_name": "South Africa",
#   "entity_type": "LOC",
#   "widely_recognizable": true,
#   "short_context": "South Africa is a country located on the southern tip of Africa, known for its diverse culture and history."
# }
#
# ---> SUCCESS: Entity South Africa (LOC) is widely recognizable. Embedding assigned.
# Processing New Zealand (86/743 - 11.6%)
# {
#   "entity_name": "New Zealand",
#   "entity_type": "LOC",
#   "widely_recognizable": true,
#   "short_context": "New Zealand is an island country in the southwestern Pacific Ocean known for its stunning landscapes and unique wildlife."
# }
#
# ---> SUCCESS: Entity New Zealand (LOC) is widely recognizable. Embedding assigned.
# Processing Springboks (87/743 - 11.7%)
# {
#   "entity_name": "Springboks",
#   "entity_type": "Organization",
#   "widely_recognizable": true,
#   "short_context": "The Springboks are the national rugby union team of South Africa."
# }
#
# ---> SUCCESS: Entity Springboks (ORG) is widely recognizable. Embedding assigned.
# Processing All Blacks (88/743 - 11.8%)
# {
#   "entity_name": "All Blacks",
#   "entity_type": "ORG",
#   "widely_recognizable": true,
#   "short_context": "The All Blacks are the national rugby union team of New Zealand, renowned for their skill and the haka."
# }
#
# ---> SUCCESS: Entity All Blacks (ORG) is widely recognizable. Embedding assigned.
# Processing Argentina (89/743 - 12.0%)
# {
#   "entity_name": "Argentina",
#   "entity_type": "LOC",
#   "widely_recognizable": true,
#   "short_context": "Argentina is a country located in South America, known for its tango, wine, and diverse landscapes."
# }
#
# ---> SUCCESS: Entity Argentina (LOC) is widely recognizable. Embedding assigned.
# Processing Ireland (90/743 - 12.1%)
# {
#   "entity_name": "Ireland",
#   "entity_type": "LOC",
#   "widely_recognizable": true,
#   "short_context": "Ireland is an island nation in the North Atlantic, known for its rich history and culture."
# }
#
# ---> SUCCESS: Entity Ireland (LOC) is widely recognizable. Embedding assigned.
# Processing Ian Foster (91/743 - 12.2%)
# {
#   "entity_name": "Ian Foster",
#   "entity_type": "Person",
#   "widely_recognizable": true,
#   "short_context": "Ian Foster is a prominent computer scientist known for his work in distributed computing and grid computing, and is a professor at the University of Chicago."
# }
#
# ---> SUCCESS: Entity Ian Foster (PER) is widely recognizable. Embedding assigned.
# Processing European Union (92/743 - 12.4%)
# {
#   "entity_name": "European Union",
#   "entity_type": "ORG",
#   "widely_recognizable": true,
#   "short_context": "The European Union is a political and economic union of 27 member states located primarily in Europe."
# }
#
# ---> SUCCESS: Entity European Union (ORG) is widely recognizable. Embedding assigned.
# Processing X (93/743 - 12.5%)
# {"entity_name": "X", "entity_type": "Organization", "widely_recognizable": false, "short_context": ""}
#
# ---> DEFAULT EMBEDDING: Entity X (ORG) is not widely recognizable. Default embedding assigned.
# Processing EU Commission (94/743 - 12.7%)
# {
#   "entity_name": "EU Commission",
#   "entity_type": "Organization",
#   "widely_recognizable": true,
#   "short_context": "The EU Commission is the executive branch of the European Union, responsible for proposing legislation, implementing decisions, and managing the EU's day-to-day business."
# }
#
# ---> SUCCESS: Entity EU Commission (ORG) is widely recognizable. Embedding assigned.
# Processing EU (95/743 - 12.8%)
# {
#   "entity_name": "EU",
#   "entity_type": "Organization",
#   "widely_recognizable": true,
#   "short_context": "The EU is a political and economic union of 27 member states located primarily in Europe."
# }
#
# ---> SUCCESS: Entity EU (ORG) is widely recognizable. Embedding assigned.
# Processing Meta (96/743 - 12.9%)
# {
#   "entity_name": "Meta",
#   "entity_type": "ORG",
#   "widely_recognizable": true,
#   "short_context": "Meta, formerly Facebook, is a multinational technology conglomerate known for social media platforms like Facebook, Instagram, and WhatsApp."
# }
#
# ---> SUCCESS: Entity Meta (ORG) is widely recognizable. Embedding assigned.
# Processing Elon Musk (97/743 - 13.1%)
# {
#   "entity_name": "Elon Musk",
#   "entity_type": "Person",
#   "widely_recognizable": true,
#   "short_context": "Elon Musk is a well-known entrepreneur and business magnate, best known as the founder of SpaceX and co-founder of Tesla."
# }
#
# ---> SUCCESS: Entity Elon Musk (PER) is widely recognizable. Embedding assigned.
# Processing Musk (98/743 - 13.2%)
# {
#   "entity_name": "Musk",
#   "entity_type": "Person",
#   "widely_recognizable": true,
#   "short_context": "Elon Musk is a well-known entrepreneur and business magnate, primarily known as the founder, CEO, and CTO of SpaceX; angel investor, CEO, and product architect of Tesla, Inc."
# }
#
# ---> SUCCESS: Entity Musk (PER) is widely recognizable. Embedding assigned.
# Processing Iran (99/743 - 13.3%)
# {
#   "entity_name": "Iran",
#   "entity_type": "LOC",
#   "widely_recognizable": true,
#   "short_context": "Iran is a country in Western Asia, known for its rich history and geopolitical significance."
# }
#
# ---> SUCCESS: Entity Iran (LOC) is widely recognizable. Embedding assigned.
# Processing DeepMind (100/743 - 13.5%)
# {
#   "entity_name": "DeepMind",
#   "entity_type": "Organization",
#   "widely_recognizable": true,
#   "short_context": "DeepMind is a leading artificial intelligence research company responsible for breakthroughs like AlphaGo and Gemini."
# }
#
# ---> SUCCESS: Entity DeepMind (ORG) is widely recognizable. Embedding assigned.
# Processing Greg Brockman (101/743 - 13.6%)
# {
#   "entity_name": "Greg Brockman",
#   "entity_type": "Person",
#   "widely_recognizable": true,
#   "short_context": "Greg Brockman is the President and Chairman of OpenAI, a leading artificial intelligence research and deployment company."
# }
#
# ---> SUCCESS: Entity Greg Brockman (PER) is widely recognizable. Embedding assigned.
# Processing OpenAI (102/743 - 13.7%)
# {
#   "entity_name": "OpenAI",
#   "entity_type": "Organization",
#   "widely_recognizable": true,
#   "short_context": "OpenAI is a leading artificial intelligence research and deployment company known for developing models like ChatGPT and DALL-E."
# }
#
# ---> SUCCESS: Entity OpenAI (ORG) is widely recognizable. Embedding assigned.
# Processing Microsoft (103/743 - 13.9%)
# {
#   "entity_name": "Microsoft",
#   "entity_type": "ORG",
#   "widely_recognizable": true,
#   "short_context": "Microsoft is a multinational technology corporation that develops, manufactures, licenses, supports and sells computer software, consumer electronics and personal computers and related services."
# }
#
# ---> SUCCESS: Entity Microsoft (ORG) is widely recognizable. Embedding assigned.
# Processing Treasury (104/743 - 14.0%)
# == Pausing code execution to cool down GPU... (79) ==
# {
#   "entity_name": "Treasury",
#   "entity_type": "Organization",
#   "widely_recognizable": true,
#   "short_context": "The Treasury Department is the executive agency responsible for managing the U.S. economy."
# }
#
# ---> SUCCESS: Entity Treasury (ORG) is widely recognizable. Embedding assigned.
# Processing S & P (105/743 - 14.1%)
# == Pausing code execution to cool down GPU... (79) ==
# {
#   "entity_name": "S & P",
#   "entity_type": "Organization",
#   "widely_recognizable": true,
#   "short_context": "S & P Global is a leading provider of ratings, benchmarks, and analytics in the financial industry, particularly known for its stock market indices like the S&P 500."
# }
#
# ---> SUCCESS: Entity S & P (ORG) is widely recognizable. Embedding assigned.
# Processing Nasdaq (106/743 - 14.3%)
# == Pausing code execution to cool down GPU... (80) ==
# {
#   "entity_name": "Nasdaq",
#   "entity_type": "Organization",
#   "widely_recognizable": true,
#   "short_context": "Nasdaq is a global electronic marketplace for trading stocks and other securities."
# }
#
# ---> SUCCESS: Entity Nasdaq (ORG) is widely recognizable. Embedding assigned.
# Processing China (107/743 - 14.4%)
# {
#   "entity_name": "China",
#   "entity_type": "LOC",
#   "widely_recognizable": true,
#   "short_context": "China is a country in East Asia and the world's most populous nation."
# }
#
# ---> SUCCESS: Entity China (LOC) is widely recognizable. Embedding assigned.
# Processing Federal Reserve (108/743 - 14.5%)
# {
#   "entity_name": "Federal Reserve",
#   "entity_type": "ORG",
#   "widely_recognizable": true,
#   "short_context": "The Federal Reserve is the central banking system of the United States, responsible for monetary policy."
# }
#
# ---> SUCCESS: Entity Federal Reserve (ORG) is widely recognizable. Embedding assigned.
# Processing Bitcoin (109/743 - 14.7%)
# {
#   "entity_name": "Bitcoin",
#   "entity_type": "ORG",
#   "widely_recognizable": true,
#   "short_context": "Bitcoin is a decentralized digital currency, often referred to as cryptocurrency, that enables peer-to-peer transactions."
# }
#
# ---> SUCCESS: Entity Bitcoin (ORG) is widely recognizable. Embedding assigned.
# Processing Kevin McCarthy (110/743 - 14.8%)
# {
#   "entity_name": "Kevin McCarthy",
#   "entity_type": "Person",
#   "widely_recognizable": true,
#   "short_context": "Kevin McCarthy is a former Speaker of the United States House of Representatives."
# }
#
# ---> SUCCESS: Entity Kevin McCarthy (PER) is widely recognizable. Embedding assigned.
# Processing Trump (111/743 - 14.9%)
# {
#   "entity_name": "Trump",
#   "entity_type": "Person",
#   "widely_recognizable": true,
#   "short_context": "Donald Trump is a former President of the United States."
# }
#
# ---> SUCCESS: Entity Trump (PER) is widely recognizable. Embedding assigned.
# Processing Biden (112/743 - 15.1%)
# {
#   "entity_name": "Biden",
#   "entity_type": "Person",
#   "widely_recognizable": true,
#   "short_context": "Joe Biden is the current President of the United States."
# }
#
# ---> SUCCESS: Entity Biden (PER) is widely recognizable. Embedding assigned.
# Processing Bankman - Fried (113/743 - 15.2%)
# {
#   "entity_name": "Bankman - Fried",
#   "entity_type": "Person",
#   "widely_recognizable": true,
#   "short_context": "Sam Bankman-Fried is the founder and former CEO of the cryptocurrency exchange FTX, who was convicted of fraud and conspiracy."
# }
#
# ---> SUCCESS: Entity Bankman - Fried (PER) is widely recognizable. Embedding assigned.
# Processing Marc - Antoine Julliard (114/743 - 15.3%)
# {
#   "entity_name": "Marc - Antoine Julliard",
#   "entity_type": "Person",
#   "widely_recognizable": false,
#   "short_context": ""
# }
#
# ---> DEFAULT EMBEDDING: Entity Marc - Antoine Julliard (PER) is not widely recognizable. Default embedding assigned.
# Processing Adam Yedidia (115/743 - 15.5%)
# {
#   "entity_name": "Adam Yedidia",
#   "entity_type": "Person",
#   "widely_recognizable": false,
#   "short_context": ""
# }
#
# ---> DEFAULT EMBEDDING: Entity Adam Yedidia (PER) is not widely recognizable. Default embedding assigned.
# Processing Matt Huang (116/743 - 15.6%)
# {
#   "entity_name": "Matt Huang",
#   "entity_type": "Person",
#   "widely_recognizable": false,
#   "short_context": ""
# }
#
# ---> DEFAULT EMBEDDING: Entity Matt Huang (PER) is not widely recognizable. Default embedding assigned.
# Processing Alphabet (117/743 - 15.7%)
# {
#   "entity_name": "Alphabet",
#   "entity_type": "Organization",
#   "widely_recognizable": true,
#   "short_context": "Alphabet is the parent company of Google and several other companies."
# }
#
# ---> SUCCESS: Entity Alphabet (ORG) is widely recognizable. Embedding assigned.
# Processing Epic Games (118/743 - 15.9%)
# {
#   "entity_name": "Epic Games",
#   "entity_type": "ORG",
#   "widely_recognizable": true,
#   "short_context": "Epic Games is a well-known video game and software developer, famous for creating Fortnite and the Unreal Engine."
# }
#
# ---> SUCCESS: Entity Epic Games (ORG) is widely recognizable. Embedding assigned.
# Processing Packers (119/743 - 16.0%)
# {
#   "entity_name": "Packers",
#   "entity_type": "Organization",
#   "widely_recognizable": true,
#   "short_context": "The Packers are a professional American football team based in Green Bay, Wisconsin."
# }
#
# ---> SUCCESS: Entity Packers (ORG) is widely recognizable. Embedding assigned.
# Processing Jordan Love (120/743 - 16.2%)
# {
#   "entity_name": "Jordan Love",
#   "entity_type": "Person",
#   "widely_recognizable": true,
#   "short_context": "Jordan Love is a professional American football quarterback for the Green Bay Packers in the NFL."
# }
#
# ---> SUCCESS: Entity Jordan Love (PER) is widely recognizable. Embedding assigned.
# Processing A. J. Dillon (121/743 - 16.3%)
# {
#   "entity_name": "A. J. Dillon",
#   "entity_type": "Person",
#   "widely_recognizable": true,
#   "short_context": "A. J. Dillon is a professional American football running back for the Green Bay Packers of the National Football League (NFL)."
# }
#
# ---> SUCCESS: Entity A. J. Dillon (PER) is widely recognizable. Embedding assigned.
# Processing Christian Watson (122/743 - 16.4%)
# {
#   "entity_name": "Christian Watson",
#   "entity_type": "Person",
#   "widely_recognizable": true,
#   "short_context": "Christian Watson is a professional American football wide receiver for the Green Bay Packers."
# }
#
# ---> SUCCESS: Entity Christian Watson (PER) is widely recognizable. Embedding assigned.
# Processing Romeo Doubs (123/743 - 16.6%)
# {
#   "entity_name": "Romeo Doubs",
#   "entity_type": "Person",
#   "widely_recognizable": true,
#   "short_context": "Romeo Doubs is a professional American football wide receiver for the Green Bay Packers of the National Football League (NFL)."
# }
#
# ---> SUCCESS: Entity Romeo Doubs (PER) is widely recognizable. Embedding assigned.
# Processing Rashee Rice (124/743 - 16.7%)
# {
#   "entity_name": "Rashee Rice",
#   "entity_type": "Person",
#   "widely_recognizable": true,
#   "short_context": "Rashee Rice is a wide receiver for the Kansas City Chiefs in the National Football League (NFL)."
# }
#
# ---> SUCCESS: Entity Rashee Rice (PER) is widely recognizable. Embedding assigned.
# Processing Luke Musgrave (125/743 - 16.8%)
# {
#   "entity_name": "Luke Musgrave",
#   "entity_type": "Person",
#   "widely_recognizable": true,
#   "short_context": "Luke Musgrave is a professional American football tight end for the Green Bay Packers."
# }
#
# ---> SUCCESS: Entity Luke Musgrave (PER) is widely recognizable. Embedding assigned.
# Processing NBC (126/743 - 17.0%)
# {
#   "entity_name": "NBC",
#   "entity_type": "Organization",
#   "widely_recognizable": true,
#   "short_context": "NBC is a major American television network known for its news, sports, and entertainment programming."
# }
#
# ---> SUCCESS: Entity NBC (ORG) is widely recognizable. Embedding assigned.
# Processing Jaguars (127/743 - 17.1%)
# {
#   "entity_name": "Jaguars",
#   "entity_type": "Organization",
#   "widely_recognizable": true,
#   "short_context": "The Jaguars are a professional American football team based in Jacksonville, Florida."
# }
#
# ---> SUCCESS: Entity Jaguars (ORG) is widely recognizable. Embedding assigned.
# Processing Saints (128/743 - 17.2%)
# {
#   "entity_name": "Saints",
#   "entity_type": "Organization",
#   "widely_recognizable": true,
#   "short_context": "The Saints are a professional American football team based in New Orleans, Louisiana, and a member of the National Football League (NFL)."
# }
#
# ---> SUCCESS: Entity Saints (ORG) is widely recognizable. Embedding assigned.
# Processing Trevor Lawrence (129/743 - 17.4%)
# {
#   "entity_name": "Trevor Lawrence",
#   "entity_type": "Person",
#   "widely_recognizable": true,
#   "short_context": "Trevor Lawrence is a professional American football quarterback for the Jacksonville Jaguars."
# }
#
# ---> SUCCESS: Entity Trevor Lawrence (PER) is widely recognizable. Embedding assigned.
# Processing Ja (130/743 - 17.5%)
# {"entity_name": "Ja", "entity_type": "Person", "widely_recognizable": false, "short_context": ""}
#
# ---> DEFAULT EMBEDDING: Entity Ja (PER) is not widely recognizable. Default embedding assigned.
# Processing Smith (131/743 - 17.6%)
# {"entity_name": "Smith", "entity_type": "PER", "widely_recognizable": true, "short_context": "Will Smith is a famous American actor and rapper."}
#
# ---> SUCCESS: Entity Smith (PER) is widely recognizable. Embedding assigned.
# Processing Vikings (132/743 - 17.8%)
# {
#   "entity_name": "Vikings",
#   "entity_type": "ORG",
#   "widely_recognizable": true,
#   "short_context": "Vikings were Norse seafarers known for their raids and explorations from the 8th to the 11th centuries."
# }
#
# ---> SUCCESS: Entity Vikings (ORG) is widely recognizable. Embedding assigned.
# Processing Broncos (133/743 - 17.9%)
# {
#   "entity_name": "Broncos",
#   "entity_type": "Organization",
#   "widely_recognizable": true,
#   "short_context": "The Denver Broncos are a professional American football team based in Denver, Colorado."
# }
#
# ---> SUCCESS: Entity Broncos (ORG) is widely recognizable. Embedding assigned.
# Processing Joshua Dobbs (134/743 - 18.0%)
# {
#   "entity_name": "Joshua Dobbs",
#   "entity_type": "Person",
#   "widely_recognizable": true,
#   "short_context": "Joshua Dobbs is a professional American football quarterback who has played in the NFL for multiple teams."
# }
#
# ---> SUCCESS: Entity Joshua Dobbs (PER) is widely recognizable. Embedding assigned.
# Processing Do (135/743 - 18.2%)
# {"entity_name": "Do", "entity_type": "Person", "widely_recognizable": false, "short_context": ""}
#
# ---> DEFAULT EMBEDDING: Entity Do (PER) is not widely recognizable. Default embedding assigned.
# Processing AI (136/743 - 18.3%)
# {
#   "entity_name": "AI",
#   "entity_type": "ORG",
#   "widely_recognizable": true,
#   "short_context": "AI, or Artificial Intelligence, refers to the simulation of human intelligence processes by computer systems."
# }
#
# ---> SUCCESS: Entity AI (ORG) is widely recognizable. Embedding assigned.
# Processing Miami Dolphins (137/743 - 18.4%)
# {
#   "entity_name": "Miami Dolphins",
#   "entity_type": "ORG",
#   "widely_recognizable": true,
#   "short_context": "The Miami Dolphins are a professional American football team based in Miami Gardens, Florida, and compete in the National Football League (NFL)."
# }
#
# ---> SUCCESS: Entity Miami Dolphins (ORG) is widely recognizable. Embedding assigned.
# Processing Baltimore Ravens (138/743 - 18.6%)
# {
#   "entity_name": "Baltimore Ravens",
#   "entity_type": "ORG",
#   "widely_recognizable": true,
#   "short_context": "The Baltimore Ravens are a professional American football team based in Baltimore, Maryland, and compete in the NFL."
# }
#
# ---> SUCCESS: Entity Baltimore Ravens (ORG) is widely recognizable. Embedding assigned.
# Processing Pittsburgh Steelers (139/743 - 18.7%)
# {
#   "entity_name": "Pittsburgh Steelers",
#   "entity_type": "Organization",
#   "widely_recognizable": true,
#   "short_context": "The Pittsburgh Steelers are a professional American football team based in Pittsburgh, Pennsylvania, and are part of the National Football League (NFL)."
# }
#
# ---> SUCCESS: Entity Pittsburgh Steelers (ORG) is widely recognizable. Embedding assigned.
# Processing Indianapolis Colts (140/743 - 18.8%)
# {
#   "entity_name": "Indianapolis Colts",
#   "entity_type": "ORG",
#   "widely_recognizable": true,
#   "short_context": "The Indianapolis Colts are a professional American football team based in Indianapolis, Indiana, and compete in the NFL."
# }
#
# ---> SUCCESS: Entity Indianapolis Colts (ORG) is widely recognizable. Embedding assigned.
# Processing Cleveland Browns (141/743 - 19.0%)
# {
#   "entity_name": "Cleveland Browns",
#   "entity_type": "ORG",
#   "widely_recognizable": true,
# ...
#   "entity_type": "Person",
#   "widely_recognizable": true,
#   "short_context": "Noah Fant is a professional American football tight end currently playing in the NFL."
# }
#
# ---> SUCCESS: Entity Noah Fant (PER) is widely recognizable. Embedding assigned.
# Processing Dallas Goedert (698/743 - 93.9%)
# {
#   "entity_name": "Dallas Goedert",
#   "entity_type": "Person",
#   "widely_recognizable": true,
#   "short_context": "Dallas Goedert is a professional American football tight end for the Philadelphia Eagles in the NFL."
# }
#
# ---> SUCCESS: Entity Dallas Goedert (PER) is widely recognizable. Embedding assigned.
# Processing Zach Charbonnet (699/743 - 94.1%)
# {
#   "entity_name": "Zach Charbonnet",
#   "entity_type": "Person",
#   "widely_recognizable": true,
#   "short_context": "Zach Charbonnet is a professional American football running back currently playing for the Seattle Seahawks."
# }
#
# ---> SUCCESS: Entity Zach Charbonnet (PER) is widely recognizable. Embedding assigned.
# Processing Brandin Cooks (700/743 - 94.2%)
# {
#   "entity_name": "Brandin Cooks",
#   "entity_type": "Person",
#   "widely_recognizable": true,
#   "short_context": "Brandin Cooks is a professional American football wide receiver currently playing in the NFL."
# }
#
# ---> SUCCESS: Entity Brandin Cooks (PER) is widely recognizable. Embedding assigned.
# Processing Wolves (701/743 - 94.3%)
# {
#   "entity_name": "Wolves",
#   "entity_type": "Organization",
#   "widely_recognizable": true,
#   "short_context": "The Minnesota Timberwolves, often referred to as the Wolves, are a professional basketball team in the NBA."
# }
#
# ---> SUCCESS: Entity Wolves (ORG) is widely recognizable. Embedding assigned.
# Processing Austria (702/743 - 94.5%)
# {
#   "entity_name": "Austria",
#   "entity_type": "LOC",
#   "widely_recognizable": true,
#   "short_context": "Austria is a country in Central Europe, known for its mountains, music, and historical cities like Vienna and Salzburg."
# }
#
# ---> SUCCESS: Entity Austria (LOC) is widely recognizable. Embedding assigned.
# Processing Spain (703/743 - 94.6%)
# {
#   "entity_name": "Spain",
#   "entity_type": "LOC",
#   "widely_recognizable": true,
#   "short_context": "Spain is a country in southwestern Europe, known for its culture, cuisine, and history."
# }
#
# ---> SUCCESS: Entity Spain (LOC) is widely recognizable. Embedding assigned.
# Processing Pe (704/743 - 94.8%)
# {"entity_name": "Pe", "entity_type": "ORG", "widely_recognizable": false, "short_context": ""}
#
# ---> DEFAULT EMBEDDING: Entity Pe (ORG) is not widely recognizable. Default embedding assigned.
# Processing Wallabies (705/743 - 94.9%)
# == Pausing code execution to cool down GPU... (79) ==
# {
#   "entity_name": "Wallabies",
#   "entity_type": "ORG",
#   "widely_recognizable": true,
#   "short_context": "The Wallabies are the national rugby union team of Australia."
# }
#
# ---> SUCCESS: Entity Wallabies (ORG) is widely recognizable. Embedding assigned.
# Processing Rugby Australia (706/743 - 95.0%)
# == Pausing code execution to cool down GPU... (79) ==
# {
#   "entity_name": "Rugby Australia",
#   "entity_type": "Organization",
#   "widely_recognizable": true,
#   "short_context": "Rugby Australia is the national governing body for rugby union in Australia."
# }
#
# ---> SUCCESS: Entity Rugby Australia (ORG) is widely recognizable. Embedding assigned.
# Processing Diamondbacks (707/743 - 95.2%)
# == Pausing code execution to cool down GPU... (80) ==
# {
#   "entity_name": "Diamondbacks",
#   "entity_type": "ORG",
#   "widely_recognizable": true,
#   "short_context": "The Arizona Diamondbacks are a professional baseball team based in Phoenix, Arizona."
# }
#
# ---> SUCCESS: Entity Diamondbacks (ORG) is widely recognizable. Embedding assigned.
# Processing Fox (708/743 - 95.3%)
# == Pausing code execution to cool down GPU... (80) ==
# {
#   "entity_name": "Fox",
#   "entity_type": "ORG",
#   "widely_recognizable": true,
#   "short_context": "Fox Corporation is a global media and entertainment company, known for its news and sports channels."
# }
#
# ---> SUCCESS: Entity Fox (ORG) is widely recognizable. Embedding assigned.
# Processing American League (709/743 - 95.4%)
# {
#   "entity_name": "American League",
#   "entity_type": "Organization",
#   "widely_recognizable": true,
#   "short_context": "The American League is one of two leagues comprising Major League Baseball in North America."
# }
#
# ---> SUCCESS: Entity American League (ORG) is widely recognizable. Embedding assigned.
# Processing National League (710/743 - 95.6%)
# {
#   "entity_name": "National League",
#   "entity_type": "Organization",
#   "widely_recognizable": true,
#   "short_context": "The National League is a professional baseball league in North America, one of the two leagues constituting Major League Baseball."
# }
#
# ---> SUCCESS: Entity National League (ORG) is widely recognizable. Embedding assigned.
# Processing NL (711/743 - 95.7%)
# {"entity_name": "NL", "entity_type": "ORG", "widely_recognizable": false, "short_context": ""}
#
# ---> DEFAULT EMBEDDING: Entity NL (ORG) is not widely recognizable. Default embedding assigned.
# Processing New York Mets (712/743 - 95.8%)
# {
#   "entity_name": "New York Mets",
#   "entity_type": "ORG",
#   "widely_recognizable": true,
#   "short_context": "The New York Mets are a professional baseball team based in New York City."
# }
#
# ---> SUCCESS: Entity New York Mets (ORG) is widely recognizable. Embedding assigned.
# Processing Los Angeles Angels (713/743 - 96.0%)
# {
#   "entity_name": "Los Angeles Angels",
#   "entity_type": "Organization",
#   "widely_recognizable": true,
#   "short_context": "The Los Angeles Angels are a professional baseball team based in Anaheim, California, competing in Major League Baseball."
# }
#
# ---> SUCCESS: Entity Los Angeles Angels (ORG) is widely recognizable. Embedding assigned.
# Processing Boston Dynamics (714/743 - 96.1%)
# {
#   "entity_name": "Boston Dynamics",
#   "entity_type": "Organization",
#   "widely_recognizable": true,
#   "short_context": "Boston Dynamics is a leading engineering and robotics design company known for developing advanced robots like Spot and Atlas."
# }
#
# ---> SUCCESS: Entity Boston Dynamics (ORG) is widely recognizable. Embedding assigned.
# Processing Tesla (715/743 - 96.2%)
# {
#   "entity_name": "Tesla",
#   "entity_type": "ORG",
#   "widely_recognizable": true,
#   "short_context": "Tesla is a well-known electric vehicle and clean energy company."
# }
#
# ---> SUCCESS: Entity Tesla (ORG) is widely recognizable. Embedding assigned.
# Processing Yoshinobu Yamamoto (716/743 - 96.4%)
# {
#   "entity_name": "Yoshinobu Yamamoto",
#   "entity_type": "Person",
#   "widely_recognizable": true,
#   "short_context": "Yoshinobu Yamamoto is a Japanese professional baseball pitcher currently playing for the Los Angeles Dodgers."
# }
#
# ---> SUCCESS: Entity Yoshinobu Yamamoto (PER) is widely recognizable. Embedding assigned.
# Processing New York Yankees (717/743 - 96.5%)
# {
#   "entity_name": "New York Yankees",
#   "entity_type": "ORG",
#   "widely_recognizable": true,
#   "short_context": "The New York Yankees are a professional baseball team based in New York City and are one of the most successful teams in Major League Baseball."
# }
#
# ---> SUCCESS: Entity New York Yankees (ORG) is widely recognizable. Embedding assigned.
# Processing Boston Red Sox (718/743 - 96.6%)
# {
#   "entity_name": "Boston Red Sox",
#   "entity_type": "ORG",
#   "widely_recognizable": true,
#   "short_context": "The Boston Red Sox are a professional baseball team based in Boston, Massachusetts, and are members of Major League Baseball."
# }
#
# ---> SUCCESS: Entity Boston Red Sox (ORG) is widely recognizable. Embedding assigned.
# Processing Mike Maignan (719/743 - 96.8%)
# {
#   "entity_name": "Mike Maignan",
#   "entity_type": "Person",
#   "widely_recognizable": true,
#   "short_context": "Mike Maignan is a professional football goalkeeper who plays for AC Milan and the France national team."
# }
#
# ---> SUCCESS: Entity Mike Maignan (PER) is widely recognizable. Embedding assigned.
# Processing Alexander Mattison (720/743 - 96.9%)
# {
#   "entity_name": "Alexander Mattison",
#   "entity_type": "Person",
#   "widely_recognizable": true,
#   "short_context": "Alexander Mattison is a professional American football running back for the Minnesota Vikings."
# }
#
# ---> SUCCESS: Entity Alexander Mattison (PER) is widely recognizable. Embedding assigned.
# Processing Jarrod Bowen (721/743 - 97.0%)
# {
#   "entity_name": "Jarrod Bowen",
#   "entity_type": "Person",
#   "widely_recognizable": true,
#   "short_context": "Jarrod Bowen is a professional footballer who plays as a winger for West Ham United and the England national team."
# }
#
# ---> SUCCESS: Entity Jarrod Bowen (PER) is widely recognizable. Embedding assigned.
# Processing Golden State Warriors (722/743 - 97.2%)
# {
#   "entity_name": "Golden State Warriors",
#   "entity_type": "ORG",
#   "widely_recognizable": true,
#   "short_context": "The Golden State Warriors are a professional basketball team based in San Francisco, California, and are well-known for their success in the NBA."
# }
#
# ---> SUCCESS: Entity Golden State Warriors (ORG) is widely recognizable. Embedding assigned.
# Processing Warriors (723/743 - 97.3%)
# {
#   "entity_name": "Warriors",
#   "entity_type": "Organization",
#   "widely_recognizable": true,
#   "short_context": "The Golden State Warriors are a professional basketball team based in San Francisco, California."
# }
#
# ---> SUCCESS: Entity Warriors (ORG) is widely recognizable. Embedding assigned.
# Processing Kyle Larson (724/743 - 97.4%)
# {
#   "entity_name": "Kyle Larson",
#   "entity_type": "Person",
#   "widely_recognizable": true,
#   "short_context": "Kyle Larson is a professional race car driver, notably competing in NASCAR and known for winning the 2021 NASCAR Cup Series championship."
# }
#
# ---> SUCCESS: Entity Kyle Larson (PER) is widely recognizable. Embedding assigned.
# Processing Chad Ryland (725/743 - 97.6%)
# {
#   "entity_name": "Chad Ryland",
#   "entity_type": "Person",
#   "widely_recognizable": true,
#   "short_context": "Chad Ryland is a professional American football placekicker for the New England Patriots."
# }
#
# ---> SUCCESS: Entity Chad Ryland (PER) is widely recognizable. Embedding assigned.
# Processing Finland (726/743 - 97.7%)
# {
#   "entity_name": "Finland",
#   "entity_type": "LOC",
#   "widely_recognizable": true,
#   "short_context": "Finland is a Nordic country in Northern Europe, known for its saunas, lakes and forests."
# }
#
# ---> SUCCESS: Entity Finland (LOC) is widely recognizable. Embedding assigned.
# Processing Walmart Plus (727/743 - 97.8%)
# {
#   "entity_name": "Walmart Plus",
#   "entity_type": "Organization",
#   "widely_recognizable": true,
#   "short_context": "Walmart Plus is a paid membership program offered by Walmart that provides benefits like free shipping and discounts."
# }
#
# ---> SUCCESS: Entity Walmart Plus (ORG) is widely recognizable. Embedding assigned.
# Processing Bryce Young (728/743 - 98.0%)
# {
#   "entity_name": "Bryce Young",
#   "entity_type": "Person",
#   "widely_recognizable": true,
#   "short_context": "Bryce Young is a professional American football quarterback for the Carolina Panthers, and was the first overall pick in the 2023 NFL Draft."
# }
#
# ---> SUCCESS: Entity Bryce Young (PER) is widely recognizable. Embedding assigned.
# Processing Young (729/743 - 98.1%)
# {"entity_name": "Young", "entity_type": "Person", "widely_recognizable": false, "short_context": ""}
#
# ---> DEFAULT EMBEDDING: Entity Young (PER) is not widely recognizable. Default embedding assigned.
# Processing Arizona State (730/743 - 98.3%)
# {
#   "entity_name": "Arizona State",
#   "entity_type": "ORG",
#   "widely_recognizable": true,
#   "short_context": "Arizona State University is a public research university in Tempe, Arizona."
# }
#
# ---> SUCCESS: Entity Arizona State (ORG) is widely recognizable. Embedding assigned.
# Processing Ange Postecoglou (731/743 - 98.4%)
# {
#   "entity_name": "Ange Postecoglou",
#   "entity_type": "Person",
#   "widely_recognizable": true,
#   "short_context": "Ange Postecoglou is a professional football manager, currently managing Tottenham Hotspur in the English Premier League."
# }
#
# ---> SUCCESS: Entity Ange Postecoglou (PER) is widely recognizable. Embedding assigned.
# Processing Ryan Blaney (732/743 - 98.5%)
# {
#   "entity_name": "Ryan Blaney",
#   "entity_type": "Person",
#   "widely_recognizable": true,
#   "short_context": "Ryan Blaney is a professional stock car racing driver in the NASCAR Cup Series."
# }
#
# ---> SUCCESS: Entity Ryan Blaney (PER) is widely recognizable. Embedding assigned.
# Processing Turkey (733/743 - 98.7%)
# {
#   "entity_name": "Turkey",
#   "entity_type": "LOC",
#   "widely_recognizable": true,
#   "short_context": "Turkey is a country located in both Europe and Asia, known for its rich history and cultural heritage."
# }
#
# ---> SUCCESS: Entity Turkey (LOC) is widely recognizable. Embedding assigned.
# Processing Rhamondre Stevenson (734/743 - 98.8%)
# {
#   "entity_name": "Rhamondre Stevenson",
#   "entity_type": "Person",
#   "widely_recognizable": true,
#   "short_context": "Rhamondre Stevenson is a professional American football running back for the New England Patriots."
# }
#
# ---> SUCCESS: Entity Rhamondre Stevenson (PER) is widely recognizable. Embedding assigned.
# Processing Jonathan Taylor (735/743 - 98.9%)
# {
#   "entity_name": "Jonathan Taylor",
#   "entity_type": "Person",
#   "widely_recognizable": true,
#   "short_context": "Jonathan Taylor is a prominent American football running back who played for the Indianapolis Colts."
# }
#
# ---> SUCCESS: Entity Jonathan Taylor (PER) is widely recognizable. Embedding assigned.
# Processing Ezekiel Elliott (736/743 - 99.1%)
# {
#   "entity_name": "Ezekiel Elliott",
#   "entity_type": "Person",
#   "widely_recognizable": true,
#   "short_context": "Ezekiel Elliott is a former NFL running back who played for the Dallas Cowboys and New England Patriots."
# }
#
# ---> SUCCESS: Entity Ezekiel Elliott (PER) is widely recognizable. Embedding assigned.
# Processing Phoenix (737/743 - 99.2%)
# {
#   "entity_name": "Phoenix",
#   "entity_type": "LOC",
#   "widely_recognizable": true,
#   "short_context": "Phoenix is a major city, the capital of Arizona, known for its warm climate and desert landscape."
# }
#
# ---> SUCCESS: Entity Phoenix (LOC) is widely recognizable. Embedding assigned.
# Processing Jesse Bradley (738/743 - 99.3%)
# {
#   "entity_name": "Jesse Bradley",
#   "entity_type": "Person",
#   "widely_recognizable": true,
#   "short_context": "Jesse Bradley is a former Major League Baseball player."
# }
#
# ---> SUCCESS: Entity Jesse Bradley (PER) is widely recognizable. Embedding assigned.
# Processing Toyota (739/743 - 99.5%)
# {
#   "entity_name": "Toyota",
#   "entity_type": "ORG",
#   "widely_recognizable": true,
#   "short_context": "Toyota is a well-known Japanese multinational automotive manufacturer."
# }
#
# ---> SUCCESS: Entity Toyota (ORG) is widely recognizable. Embedding assigned.
# Processing Stellantis (740/743 - 99.6%)
# {
#   "entity_name": "Stellantis",
#   "entity_type": "Organization",
#   "widely_recognizable": true,
#   "short_context": "Stellantis is a multinational automotive manufacturing corporation formed in 2021 from the merger of Fiat Chrysler Automobiles and PSA Group."
# }
#
# ---> SUCCESS: Entity Stellantis (ORG) is widely recognizable. Embedding assigned.
# Processing NHTSA (741/743 - 99.7%)
# {
#   "entity_name": "NHTSA",
#   "entity_type": "Organization",
#   "widely_recognizable": true,
#   "short_context": "NHTSA is the National Highway Traffic Safety Administration, a U.S. government agency responsible for road and vehicle safety."
# }
#
# ---> SUCCESS: Entity NHTSA (ORG) is widely recognizable. Embedding assigned.
# Processing Waymo (742/743 - 99.9%)
# {
#   "entity_name": "Waymo",
#   "entity_type": "Organization",
#   "widely_recognizable": true,
#   "short_context": "Waymo is a leading company developing self-driving car technology."
# }
#
# ---> SUCCESS: Entity Waymo (ORG) is widely recognizable. Embedding assigned.
# Processing God (743/743 - 100.0%)
# {
#   "entity_name": "God",
#   "entity_type": "Person",
#   "widely_recognizable": true,
#   "short_context": "God is a commonly referenced concept representing a supreme being or ultimate reality in many religions."
# }
#
# ---> SUCCESS: Entity God (PER) is widely recognizable. Embedding assigned.
# Saved!

# %%
# Create and assign article summary embeddings

for node, data in G.nodes(data=True):
    if data["type"] == "article":
        try:
            summary_embedding = get_ollama_embedding(raw_entities[node]["summary"])
            data["summary_embedding"] = summary_embedding["embedding"] 
        except:
            print(f"Error with {node}, assigning default embedding.")
            data["summary_embedding"] = np.zeros(1024, dtype=np.float32) 

        #print(data["summary_embedding"])
        #break
# Out:
# Error with 250, assigning default embedding.

# %%
# Helper function to average a list of embeddings (assumed to be list of floats)
def average_embeddings(embeddings):
    """
    Given a list of embedding vectors, compute the element-wise average.
    Returns the average embedding as a list.
    """
    return np.mean(np.array(embeddings), axis=0).tolist()

# %%
# -------------------------------
# Step 1: Generate Article Embeddings
# For each article, average the embeddings of all its associated chunks.
# -------------------------------
for node, data in G.nodes(data=True):
    if data.get("type") == "article":
        chunk_embeddings = []
        # Iterate over all successors of the article (neighbors in the graph)
        for neighbor in G.successors(node):
            # Get the edge data from article to neighbor
            edge_data = G.get_edge_data(node, neighbor)
            # Check if the relation is "CONTAINS" (i.e., the article contains the chunk)
            if edge_data and edge_data.get("relation") == "CONTAINS":
                neighbor_data = G.nodes[neighbor]
                # Ensure that the chunk has an embedding
                if "embedding" in neighbor_data:
                    chunk_embeddings.append(neighbor_data["embedding"])
        # If there are chunk embeddings available, compute the average of the summary embedding and the average chunk embedding
        summary_embedding = data["summary_embedding"] 
        if chunk_embeddings:
            data["embedding"] = average_embeddings([average_embeddings(chunk_embeddings),data["summary_embedding"]])

# -------------------------------
# Step 2: Generate Embeddings for Authors, Categories, and Sources
# For each of these node types, average the embeddings of all connected article nodes.
# -------------------------------

# For author nodes: use the "AUTHORED" edge from author to article.
for node, data in G.nodes(data=True):
    if data.get("type") == "author":
        article_embeddings = []
        # Iterate over outgoing edges from the author node
        for _, target, edge_data in G.out_edges(node, data=True):
            if edge_data.get("relation") == "AUTHORED":
                target_data = G.nodes[target]
                if "embedding" in target_data:
                    article_embeddings.append(target_data["embedding"])
        if article_embeddings:
            data["embedding"] = average_embeddings(article_embeddings)

# For category nodes: use the "COVERED_IN" edge from category to article.
for node, data in G.nodes(data=True):
    if data.get("type") == "category":
        article_embeddings = []
        # Iterate over outgoing edges from the category node
        for _, target, edge_data in G.out_edges(node, data=True):
            if edge_data.get("relation") == "COVERED_IN":
                target_data = G.nodes[target]
                if "embedding" in target_data:
                    article_embeddings.append(target_data["embedding"])
        if article_embeddings:
            data["embedding"] = average_embeddings(article_embeddings)

# For source nodes: use the "PUBLISHES" edge from source to article.
for node, data in G.nodes(data=True):
    if data.get("type") == "source":
        article_embeddings = []
        # Iterate over outgoing edges from the source node
        for _, target, edge_data in G.out_edges(node, data=True):
            if edge_data.get("relation") == "PUBLISHES":
                target_data = G.nodes[target]
                if "embedding" in target_data:
                    article_embeddings.append(target_data["embedding"])
        if article_embeddings:
            data["embedding"] = average_embeddings(article_embeddings)

# %%
# Ensure every node has an embedding assigned.
# If missing, report the node and assign a default zero embedding.

missing_nodes = []
default_embedding = None

# Determine the embedding dimension from an existing node with an embedding
for node, data in G.nodes(data=True):
    if "embedding" in data:
        # If the embedding is a dict (for "chunk" nodes), extract the list from key "embedding"
        if isinstance(data["embedding"], dict):
            emb_list = data["embedding"].get("embedding")
            if emb_list is not None:
                default_dim = len(emb_list)
                # For chunk nodes, we expect the embedding to be a dict
                default_embedding = {"embedding": [0.0] * default_dim}
                break
        # Otherwise, if it's a list (as for aggregated embeddings)
        elif isinstance(data["embedding"], list):
            default_dim = len(data["embedding"])
            default_embedding = [0.0] * default_dim
            break

if default_embedding is None:
    print("Could not determine the embedding dimension. No node with an assigned embedding was found.")
else:
    # Iterate over all nodes to ensure each has an embedding
    for node, data in G.nodes(data=True):
        if "embedding" not in data:
            missing_nodes.append(node)
            # For "chunk" type nodes, assign a dict structure; otherwise, assign a simple list.
            if data.get("type") == "chunk":
                data["embedding"] = {"embedding": [0.0] * default_dim}
            else:
                data["embedding"] = [0.0] * default_dim

    print("Nodes missing embeddings:", missing_nodes)
# Out:
# Nodes missing embeddings: []

# %%
# -------------------------------
# Graph Summary Statistics
# -------------------------------

# Total number of nodes and edges
total_nodes = G.number_of_nodes()
total_edges = G.number_of_edges()

# Count nodes by type
node_type_counts = {}
for node, data in G.nodes(data=True):
    node_type = data.get("type", "unknown")
    node_type_counts[node_type] = node_type_counts.get(node_type, 0) + 1

# Calculate graph density
density = nx.density(G)

# Calculate average degree (using overall degree: sum of in-degree and out-degree)
degrees = dict(G.degree())
avg_degree = sum(degrees.values()) / total_nodes if total_nodes > 0 else 0

# Calculate the number of strongly and weakly connected components
num_strongly_connected = nx.number_strongly_connected_components(G)
num_weakly_connected = nx.number_weakly_connected_components(G)

# Print the network summary
print("Network Summary:")
print(f"Total nodes: {total_nodes}")
print("Nodes by type:")
for node_type, count in node_type_counts.items():
    print(f"  {node_type}: {count}")
print(f"Total edges: {total_edges}")
print(f"Graph density: {density:.4f}")
print(f"Average degree: {avg_degree:.2f}")
print(f"Number of strongly connected components: {num_strongly_connected}")
print(f"Number of weakly connected components: {num_weakly_connected}")
# Out:
# Network Summary:
# Total nodes: 3367
# Nodes by type:
#   article: 609
#   author: 300
#   source: 49
#   category: 6
#   chunk: 1660
#   entity_ORG: 314
#   entity_LOC: 90
#   entity_PER: 339
# Total edges: 15831
# Graph density: 0.0014
# Average degree: 9.40
# Number of strongly connected components: 1
# Number of weakly connected components: 1

# %%
with open("../data/multihop_graph_w_sem_embeddings.pkl", "wb") as f:
    pickle.dump(G, f)
print("Graph saved!")
# Out:
# Graph saved!

# %% [markdown]
# ## Visualizing the embedding space with TSNE

# %%
from sklearn.manifold import TSNE
import plotly.express as px

# %%
# -------------------------------
# Step 1: Extract embeddings and node info from the graph
# -------------------------------
embedding_list = []  # List to store embedding vectors
node_ids = []        # List to store node IDs
node_types = []      # List to store node types (e.g., article, chunk, etc.)
node_categories = [] 
node_authors = [] 
node_sources = [] 

# Iterate over all nodes in the graph G
for node, data in G.nodes(data=True):
    if "embedding" in data:
        embedding_list.append(data["embedding"])
        node_ids.append(node)
        node_types.append(data.get("type", "unknown"))
        node_categories.append(data.get("category", "unknown"))
        node_authors.append(data.get("author", "unknown"))
        node_sources.append(data.get("source", "unknown"))


# Check how many embeddings were extracted
print(f"Extracted embeddings from {len(embedding_list)} nodes.")

# -------------------------------
# Step 2: Convert embeddings to a numpy array
# -------------------------------
embeddings_array = np.array(embedding_list)
print(f"Embeddings array shape: {embeddings_array.shape}")

# -------------------------------
# Step 3: Apply t-SNE to reduce the embeddings to 2D
# -------------------------------
tsne = TSNE(n_components=2, random_state=42, perplexity=1000)
embeddings_2d = tsne.fit_transform(embeddings_array)
print("t-SNE transformation complete.")

# -------------------------------
# Step 4: Create a DataFrame with the 2D coordinates and node information
# -------------------------------
df_tsne = pd.DataFrame(embeddings_2d, columns=['x', 'y'])
df_tsne['node_id'] = node_ids
df_tsne['node_type'] = node_types
df_tsne['category'] = node_categories 
df_tsne['author'] = node_authors
df_tsne['source'] = node_sources 

# -------------------------------
# Step 5: Create an interactive scatter plot using Plotly
# -------------------------------
color_map = {
    "article": "blue",
    "author": "red",
    "source": "green",
    "category": "orange",
    "chunk": "purple"
}

fig = px.scatter(
    df_tsne,
    x='x',
    y='y',
    color='node_type',
    color_discrete_map=color_map,
    hover_data=['node_id', 'node_type', 'category', 'author', 'source'],
    title="t-SNE Visualization of Node Embeddings",
    width=1000,
    height=1000
)
fig.show()
# Out:
# Extracted embeddings from 3367 nodes.
# Embeddings array shape: (3367, 1024)
# t-SNE transformation complete.
